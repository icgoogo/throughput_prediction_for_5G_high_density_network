# %% [markdown]
# <a href="https://colab.research.google.com/github/hirdeshkumar2407/NMDA-FP/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project 9 — Throughput Prediction in a Dense 5G Deployment**

# %% [markdown]
# **Group H**
#
# Members:
#
# - Hirdesh Kumar
# - Hammad Syarif
# - Zahra Sadat Parviss

# %% [markdown]
# ## Abstract
# This project investigates whether user throughput in a dense 5G deployment can be predicted using user-terminal and radio-unit features from the ACC Arena dataset. The study compares Random Forest and Neural Network models, engineers the Team 9 crowd-density feature based on the number of users within X meters of each target device, and simulates Vertical Federated Learning by splitting features between user-terminal and radio-unit sides. The results show that neural network models achieve stronger log-scale performance than Random Forest models, while the VFL models remain close to their centralized counterparts.

# %% [markdown]
# ## 1. Introduction
#
# Throughput prediction is an important task in dense 5G deployments because user performance depends on both radio conditions and local user behavior. In crowded environments such as ACC Arena, throughput is affected by signal quality, resource usage, traffic state, user mobility, and nearby user density.
#
# The goal of this project is to predict downlink throughput and compare centralized learning with a simulated Vertical Federated Learning setup.

# %% [markdown]
# ## 2. Project Objectives
#
# The Project 9 requirements are:
#
# 1. Perform throughput regression on ACC Arena users.
# 2. Compare two models: Random Forest and Neural Network.
# 3. Use radio and user-terminal features such as SINR, BLER, PRB, traffic state, and user position.
# 4. Engineer the Team 9 feature: number of users within X meters from the target device.
# 5. Simulate Vertical Federated Learning by splitting features between user-terminal and radio-unit sides.
# 6. Use a combined linear regressor for the VFL baseline.
# 7. Compare VFL results with more complex models trained on centralized or single-device features.

# %%
####### Setup and Config
from __future__ import annotations
from sklearn.model_selection import GroupKFold

from sklearn.model_selection import GroupKFold
import gc
import os
import time
import copy
import random
import warnings
from dataclasses import dataclass
from typing import Dict, Iterable, List, Optional, Sequence, Tuple

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.spatial import cKDTree, KDTree
from tqdm.auto import tqdm
import joblib


# ── scikit‑learn ──
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import RandomizedSearchCV, KFold
from sklearn.metrics import (
    accuracy_score, f1_score, roc_auc_score,
    mean_absolute_error, mean_squared_error, r2_score,
    classification_report, confusion_matrix
)
from sklearn.linear_model import LogisticRegression, Ridge

# ── RAPIDS cuML (GPU Random Forest) ──
try:
    HAS_CUML = True
    import cupy as cp
    from cuml.ensemble import RandomForestClassifier as cuRFClassifier
    from cuml.ensemble import RandomForestRegressor as cuRFRegressor
except Exception:
    cp = None
    cuRFClassifier = None
    cuRFRegressor = None
    HAS_CUML = False

# ── PyTorch ──
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

warnings.filterwarnings("ignore")

CPU_WORKERS = os.cpu_count() or -1
print(f"CPU workers: {CPU_WORKERS}")
# Out:
# CPU workers: 4

# %% [markdown]
# ## 3. Dataset Description
#
# The dataset comes from the ACC Arena dense 5G deployment scenario. Each sample contains user-terminal information, radio-unit measurements, traffic state, user position, and throughput values. The main variables include timestamp, user ID, position coordinates, radio-unit association, SINR, BLER, PRB, traffic state, and downlink throughput.
#
# The dataset is large, so the notebook uses memory-aware preprocessing and aggregation before model training.

# %%
# ── Kaggle paths & runtime switches ─────────────────────────────

input_root = "/kaggle/input/datasets/hammadsyarif/l5ghdd-ds"
acc_arena = os.path.join(input_root, "Acc Arena")
working = "/kaggle/working"

master_df = "master_quantile_full_one_min_df.parquet"
engineered_df = "arena_quantile_full_one_min_df.parquet"

cached_master = os.path.join(working, master_df)
cached_feat = os.path.join(working, engineered_df)

ds_master = os.path.join(input_root, master_df)
ds_feat = os.path.join(input_root, engineered_df)

fast_mode = True          # smaller models / optional subsampling
run_sequence_model = False  # CNN+GRU is slow; enable when RF baseline works
random_state = 42

print("INPUT_ROOT:", input_root)
print("Exists:", os.path.isdir(input_root))
print("FAST_MODE:", fast_mode)
# Out:
# INPUT_ROOT: /kaggle/input/datasets/hammadsyarif/l5ghdd-ds
# Exists: True
# FAST_MODE: True

# %%
# ── GPU RF backend (optional) ───────────────────────────────────
try:
    USE_GPU_RF = True
    print("Backend: GPU Random Forest (cuML)")
except Exception as e:
    cp = None
    USE_GPU_RF = False
    print("Backend: CPU Random Forest (sklearn)")
    print(e)

def clear_memory():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache() # <--- CRITICAL FOR PYTORCH
    if cp is not None:
        try:
            cp.get_default_memory_pool().free_all_blocks()
        except Exception:
            pass

def to_numpy(x):
    if cp is not None and isinstance(x, cp.ndarray):
        return cp.asnumpy(x)
    return np.asarray(x)
# Out:
# Backend: GPU Random Forest (cuML)

# %%
# Further reducing max_user_id from 
# 0  to 11 999 to process 12000 users (0-999)
max_user_id = 11999
chunk_size = 500

# List of subdirectories containing the metric files
data_subdirs = {
    "Positions": f"{acc_arena}/Positions_Acc_Arena/",
    "Throughput": f"{acc_arena}/Throughput_Acc_Arena/",
    "SINRUL": f"{acc_arena}/SINR_Acc_Arena/",
    "SINRDL": f"{acc_arena}/SINR_Acc_Arena/",
    "PRB": f"{acc_arena}/PRB_Acc_Arena/",
    "RU": f"{acc_arena}/RU_Association_Acc_Arena/",
    "BLER": f"{acc_arena}/BLER_Acc_Arena/"
}

# Base filename patterns for each metric, extracted from the notebook's existing loading logic
file_patterns = {
    "Positions": "Positions_Salt_Tar_UE_Id_",
    "Throughput": "Throughput_UE_Id_",
    "SINRUL": "SINRUL_UE_Id_",
    "SINRDL": "SINRDL_UE_Id_",
    "PRB": "PRBS_UE_Id_",
    "RU": "RU_UE_Id_",
    "BLER": "BLER_UE_Id_"
}

all_files_to_process = []

for metric_name, subdir in data_subdirs.items():
    print(f"\n--- Listing {metric_name} files in {subdir} ---")
    for start_id in range(0, max_user_id + 1, chunk_size):
        end_id = start_id + chunk_size - 1
        if end_id > max_user_id:
            end_id = max_user_id

        filename_prefix = file_patterns[metric_name]
        filename = f"{filename_prefix}{start_id}_{end_id}.csv"

        # Paths are relative to DATASET_PATH because os.chdir(DATASET_PATH) was called in an earlier cell.
        expected_file_path = os.path.join(subdir, filename)
        all_files_to_process.append(expected_file_path)
        print(expected_file_path)

print(f"\nIn total, {len(all_files_to_process)} files are expected to be processed for all {max_user_id + 1} users.")
print(f"The next step would involve modifying cells that load data (e.g., cell `fp3mSLPLAj2h` and `dyWc1dl6GqgQ`)")
print(f"to iterate through these file patterns and concatenate the resulting dataframes.")
# Out:
# --- Listing Positions files in /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/ ---
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_0_499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_500_999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_1000_1499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_1500_1999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_2000_2499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_2500_2999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_3000_3499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_3500_3999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_4000_4499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_4500_4999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_5000_5499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_5500_5999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_6000_6499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_6500_6999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_7000_7499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_7500_7999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_8000_8499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_8500_8999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_9000_9499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_9500_9999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_10000_10499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_10500_10999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_11000_11499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Positions_Acc_Arena/Positions_Salt_Tar_UE_Id_11500_11999.csv
#
# --- Listing Throughput files in /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/ ---
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_0_499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_500_999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_1000_1499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_1500_1999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_2000_2499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_2500_2999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_3000_3499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_3500_3999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_4000_4499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_4500_4999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_5000_5499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_5500_5999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_6000_6499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_6500_6999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_7000_7499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_7500_7999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_8000_8499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_8500_8999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_9000_9499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_9500_9999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_10000_10499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_10500_10999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_11000_11499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/Throughput_Acc_Arena/Throughput_UE_Id_11500_11999.csv
#
# --- Listing SINRUL files in /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/ ---
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_0_499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_500_999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_1000_1499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_1500_1999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_2000_2499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_2500_2999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_3000_3499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_3500_3999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_4000_4499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_4500_4999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_5000_5499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_5500_5999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_6000_6499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_6500_6999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_7000_7499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_7500_7999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_8000_8499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_8500_8999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_9000_9499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_9500_9999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_10000_10499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_10500_10999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_11000_11499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRUL_UE_Id_11500_11999.csv
#
# --- Listing SINRDL files in /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/ ---
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_0_499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_500_999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_1000_1499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_1500_1999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_2000_2499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_2500_2999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_3000_3499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_3500_3999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_4000_4499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_4500_4999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_5000_5499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_5500_5999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_6000_6499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_6500_6999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_7000_7499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_7500_7999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_8000_8499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_8500_8999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_9000_9499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_9500_9999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_10000_10499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_10500_10999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_11000_11499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/SINR_Acc_Arena/SINRDL_UE_Id_11500_11999.csv
#
# --- Listing PRB files in /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/ ---
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_0_499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_500_999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_1000_1499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_1500_1999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_2000_2499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_2500_2999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_3000_3499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_3500_3999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_4000_4499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_4500_4999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_5000_5499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_5500_5999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_6000_6499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_6500_6999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_7000_7499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_7500_7999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_8000_8499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_8500_8999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_9000_9499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_9500_9999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_10000_10499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_10500_10999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_11000_11499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/PRB_Acc_Arena/PRBS_UE_Id_11500_11999.csv
#
# --- Listing RU files in /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/ ---
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_0_499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_500_999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_1000_1499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_1500_1999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_2000_2499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_2500_2999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_3000_3499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_3500_3999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_4000_4499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_4500_4999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_5000_5499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_5500_5999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_6000_6499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_6500_6999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_7000_7499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_7500_7999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_8000_8499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_8500_8999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_9000_9499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_9500_9999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_10000_10499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_10500_10999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_11000_11499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/RU_Association_Acc_Arena/RU_UE_Id_11500_11999.csv
#
# --- Listing BLER files in /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/ ---
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_0_499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_500_999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_1000_1499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_1500_1999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_2000_2499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_2500_2999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_3000_3499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_3500_3999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_4000_4499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_4500_4999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_5000_5499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_5500_5999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_6000_6499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_6500_6999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_7000_7499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_7500_7999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_8000_8499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_8500_8999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_9000_9499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_9500_9999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_10000_10499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_10500_10999.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_11000_11499.csv
# /kaggle/input/datasets/hammadsyarif/l5ghdd-ds/Acc Arena/BLER_Acc_Arena/BLER_UE_Id_11500_11999.csv
#
# In total, 168 files are expected to be processed for all 12000 users.
# The next step would involve modifying cells that load data (e.g., cell `fp3mSLPLAj2h` and `dyWc1dl6GqgQ`)
# to iterate through these file patterns and concatenate the resulting dataframes.

# %% [markdown]
# ## 4. Data Preprocessing and 60-Second Quantile Aggregation
#
# The raw ACC Arena telemetry is sampled every 3 seconds and stored across separate files for throughput, SINR, PRB, BLER, radio-unit association, and user positions. Because the full dataset is large, the preprocessing is performed in user chunks instead of loading all 12,000 users into memory at once.
#
# Each chunk is converted into a long user-time format, merged across measurement types, and then resampled into **60-second user-level windows**. This aggregation was selected as a practical tradeoff between temporal resolution and computational feasibility. Earlier experiments with shorter windows such as 15 seconds and 30 seconds preserved more detail but produced very large tables that were difficult to train on repeatedly in Kaggle/Colab. Longer windows reduced the data further but removed too much temporal variation.
#
# Robust quantile aggregation is used for the main throughput and radio-quality variables:
#
# - `Throughput` uses the **95th percentile** to capture near-peak sustainable throughput while reducing the influence of isolated spikes.
# - `PRB` uses the **95th percentile** to summarize high resource-block usage within the window.
# - `SINR_UL` uses the **90th percentile** to represent strong link-quality conditions.
# - `BLER` uses the **10th percentile** to represent low-error link conditions.
# - Mean aggregation is used for slowly varying variables such as position and altitude, and as a complementary statistic for SINR and BLER.
#
# The resulting master table contains **one row per user per 60-second window** with aggregated features ready for feature engineering and modeling. The processed dataframe is cached in Parquet format so later notebook runs do not need to rebuild the full dataset from the raw CSV files.

# %%
def flatten_metric(file_path, feature_name):
    df = pd.read_csv(file_path)
    df_long = df.melt(id_vars=['time'], var_name='User_String', value_name=feature_name)
    df_long.rename(columns={'time': 'Timestamp'}, inplace=True)
    df_long['User_ID'] = df_long['User_String'].str.replace('entityStats id ', '').astype('int32')
    return df_long[['Timestamp', 'User_ID', feature_name]]

# %%
DATASET_PATH = input_root  # Ensure this variable is active in your notebook
max_user_id = 11999                 # 12,000 users total (0-11999)
chunk_size = 500

if os.path.exists(cached_master):
    print("⚡ Loading master_df from cache ...")
    master_df = pd.read_parquet(cached_master)
elif os.path.exists(ds_master):
    print("⚡ Loading master_df from datasets ...")
    master_df = pd.read_parquet(ds_master)
else:
    # ==========================================
    # 1. GLOBAL SETTINGS & INITIALIZATION
    # ==========================================
    aggregated_chunks = []
    global_origin_lat = None
    global_origin_lon = None
    
    print(f"🚀 Starting ultra-lean ingestion for {max_user_id + 1} users...")
    
    # ==========================================
    # 2. THE ISOLATED CHUNK LOOP
    # ==========================================
    for start_id in range(0, max_user_id + 1, chunk_size):
        end_id = min(start_id + chunk_size - 1, max_user_id)
        print(f"🔄 Processing file chunk: Users {start_id} to {end_id}...")
    
        # --- A. Construct File Paths ---
        base_dir = os.path.join(DATASET_PATH, acc_arena)
        tp_path      = os.path.join(base_dir, "Throughput_Acc_Arena", f"Throughput_UE_Id_{start_id}_{end_id}.csv")
        sinr_ul_path = os.path.join(base_dir, "SINR_Acc_Arena", f"SINRUL_UE_Id_{start_id}_{end_id}.csv")
        sinr_dl_path = os.path.join(base_dir, "SINR_Acc_Arena", f"SINRDL_UE_Id_{start_id}_{end_id}.csv")
        prb_path     = os.path.join(base_dir, "PRB_Acc_Arena", f"PRBS_UE_Id_{start_id}_{end_id}.csv")
        ru_path      = os.path.join(base_dir, "RU_Association_Acc_Arena", f"RU_UE_Id_{start_id}_{end_id}.csv")
        bler_path    = os.path.join(base_dir, "BLER_Acc_Arena", f"BLER_UE_Id_{start_id}_{end_id}.csv")
        pos_path     = os.path.join(base_dir, "Positions_Acc_Arena", f"Positions_Salt_Tar_UE_Id_{start_id}_{end_id}.csv")
    
        # --- B. Load and Preprocess Metrics ---
        metrics = [
            (tp_path, "Throughput"),
            (sinr_ul_c := flatten_metric(sinr_ul_path, "SINR_UL"), "SINR_UL"), # Actually keep as variables
        ]
        # (Keeping your original explicit load pattern for safety)
        tp_c      = flatten_metric(tp_path, "Throughput").drop_duplicates(subset=['Timestamp', 'User_ID'])
        sinr_ul_c = flatten_metric(sinr_ul_path, "SINR_UL").drop_duplicates(subset=['Timestamp', 'User_ID'])
        sinr_dl_c = flatten_metric(sinr_dl_path, "SINR_DL").drop_duplicates(subset=['Timestamp', 'User_ID'])
        prb_c     = flatten_metric(prb_path, "PRB").drop_duplicates(subset=['Timestamp', 'User_ID'])
        ru_c      = flatten_metric(ru_path, "RU").drop_duplicates(subset=['Timestamp', 'User_ID'])
        bler_c    = flatten_metric(bler_path, "BLER").drop_duplicates(subset=['Timestamp', 'User_ID'])
    
        # --- C. Process Positions Matrix ---
        df_pos_raw = pd.read_csv(pos_path)
        raw_matrix = df_pos_raw.values
        
        timestamps = raw_matrix[:, 0]
        data_matrix = raw_matrix[:, 1:]
        
        # Reshape and Flatten
        num_timestamps = len(timestamps)
        num_users_in_chunk = end_id - start_id + 1
        reshaped_pos = data_matrix.reshape(num_timestamps, num_users_in_chunk, 5)
        
        records = [
            [int(timestamps[t]), int(reshaped_pos[t, u, 0]), *reshaped_pos[t, u, 1:]]
            for t in range(num_timestamps)
            for u in range(num_users_in_chunk)
        ]
        
        pos_c = pd.DataFrame(records, columns=['Timestamp', 'User_ID', 'Latitude', 'Longitude', 'Altitude', 'MobileState'])
    
        # Set Global Origin for Cartesian conversion
        if global_origin_lat is None:
            global_origin_lat = pos_c['Latitude'].iloc[0]
            global_origin_lon = pos_c['Longitude'].iloc[0]
            LAT_TO_M = 111320.0
            LON_TO_M = 111320.0 * np.cos(np.radians(global_origin_lat))
        
        pos_c['X_meters'] = (pos_c['Longitude'] - global_origin_lon) * LON_TO_M
        pos_c['Y_meters'] = (pos_c['Latitude'] - global_origin_lat) * LAT_TO_M
        pos_c = pos_c.drop_duplicates(subset=['Timestamp', 'User_ID'])
    
        # --- D. Merge All Metrics ---
        chunk_df = (pos_c.merge(tp_c,      on=['Timestamp', 'User_ID'], how='inner')
                         .merge(sinr_ul_c, on=['Timestamp', 'User_ID'], how='inner')
                         .merge(sinr_dl_c, on=['Timestamp', 'User_ID'], how='inner')
                         .merge(prb_c,     on=['Timestamp', 'User_ID'], how='inner')
                         .merge(ru_c,      on=['Timestamp', 'User_ID'], how='inner')
                         .merge(bler_c,    on=['Timestamp', 'User_ID'], how='inner'))
    
        # ==========================================
        # 3. FAST 60-SECOND AGGREGATION
        # ==========================================
        chunk_df['Timestamp_DT'] = pd.to_datetime(chunk_df['Timestamp'], unit='s')
        gb = chunk_df.set_index('Timestamp_DT').groupby('User_ID')
    
        # 1. Base Aggregation (Fast)
        fast_rules = {
            'Latitude': 'mean', 'Longitude': 'mean', 'Altitude': 'mean',
            'X_meters': 'mean', 'Y_meters': 'mean',
            'SINR_UL': 'mean', 'SINR_DL': 'mean',
            'BLER': 'mean', 'RU': 'first', 'MobileState': 'first'
        }
        chunk_agg = gb.resample('60S').agg(fast_rules).dropna().reset_index()
    
        # 2. Add Quantiles (Optimized Vectorized)
        q_tp   = gb.resample('60S')['Throughput'].quantile(0.95).reset_index(name='Throughput')
        q_prb  = gb.resample('60S')['PRB'].quantile(0.95).reset_index(name='PRB')
        q_sinr = gb.resample('60S')['SINR_UL'].quantile(0.90).reset_index(name='SINR_UL_q90')
        q_bler = gb.resample('60S')['BLER'].quantile(0.10).reset_index(name='BLER_q10')
    
        # 3. Merge quantiles back
        chunk_agg = (chunk_agg.merge(q_tp,   on=['User_ID', 'Timestamp_DT'])
                              .merge(q_prb,  on=['User_ID', 'Timestamp_DT'])
                              .merge(q_sinr, on=['User_ID', 'Timestamp_DT'])
                              .merge(q_bler, on=['User_ID', 'Timestamp_DT']))
    
        # 4. Final Formatting & Downcasting
        float_cols = ['Latitude', 'Longitude', 'Altitude', 'X_meters', 'Y_meters', 
                      'Throughput', 'SINR_UL', 'SINR_DL', 'PRB', 'BLER',
                      'SINR_UL_q90', 'BLER_q10']
        
        chunk_agg[float_cols] = chunk_agg[float_cols].astype('float32')
        chunk_agg['User_ID']     = chunk_agg['User_ID'].astype('int32')
        chunk_agg['RU']          = chunk_agg['RU'].astype('int8')
        chunk_agg['MobileState'] = chunk_agg['MobileState'].astype('int8')
    
        aggregated_chunks.append(chunk_agg)
        
        # ==========================================
        # 4. EXPLICIT RAM CLEANUP (Crucial for 30GB Limit)
        # ==========================================
        del chunk_df, pos_c, tp_c, sinr_ul_c, sinr_dl_c, prb_c, ru_c, bler_c, df_pos_raw, raw_matrix, reshaped_pos, records
        gc.collect()  # Forces Python to immediately release the memory back to your OS
    
    # ==========================================
    # 5. COMPILE FINAL MASTER DATASET
    # ==========================================
    master_df = pd.concat(aggregated_chunks, ignore_index=True)
    master_df.rename(columns={'Timestamp_DT': 'Timestamp'}, inplace=True)
    master_df.to_parquet(cached_master, index=False)
    print("\n🎉 Success! Master dataset successfully extracted and compressed!")
    print(f"Final 60-Second Aggregated Shape: {master_df.shape}")
# Out:
# ⚡ Loading master_df from datasets ...

# %%
# 1. Strip away any duplicate columns
master_df = master_df.loc[:, ~master_df.columns.duplicated()].copy()
cols_to_drop = [col for col in ['Timestamp', 'index', 'level_0'] if col in master_df.columns]
master_df.drop(columns=cols_to_drop, inplace=True)

# 2. Reconstruct the accurate 60-second time gaps
master_df['Timestamp_Sec'] = master_df.groupby('User_ID').cumcount() * 60

# 3. Reorder the columns
cols = ['Timestamp_Sec', 'User_ID'] + [c for c in master_df.columns if c not in ['Timestamp_Sec', 'User_ID']]
master_df = master_df[cols]

# %% [markdown]
# ### 4.1 Computational Constraints and Final Preprocessing Design
#
# A major practical limitation of this project was the computational capacity available in Kaggle and Google Colab. The original ACC Arena dataset is very large, and early full-resolution experiments caused RAM crashes when the raw data was processed directly. Therefore, the final preprocessing pipeline was designed to balance three goals:
#
# 1. preserve the full dataset structure as much as possible;
# 2. satisfy all Project 9 requirements;
# 3. keep the notebook reproducible under realistic student-cloud computing limits.
#
# Initial experiments were performed on small subsets, such as 500 users. However, these subsets were not fully representative of the complete ACC Arena dataset because the throughput and traffic-state distributions changed noticeably when moving to the full user population. For this reason, the final pipeline avoids relying only on small-user experiments.
#
# Several temporal aggregation levels were tested, including 15 seconds, 30 seconds, 1 minute, and 2 minutes. The 15-second aggregation preserved more temporal detail but still produced around 26 million rows, which remained a major bottleneck for memory usage and repeated model training. The 2-minute aggregation reduced the data size further, but the base model results were weaker, suggesting that too much temporal variation had been smoothed away.
#
# The final choice was therefore **1-minute aggregation**, which produced around 6 million user-time rows. This was the most practical tradeoff: it reduced the dataset enough to allow model training and cross-validation while still preserving all users and the main temporal structure. In other words, the raw measurements were not simply discarded; they were summarized into robust user-time aggregates that retain the main radio and throughput behavior.

# %% [markdown]
# ## 5. Exploratory Data Analysis
#
# Before training the models, the dataset is explored to understand the distribution of throughput, radio quality, radio-unit usage, and traffic states. This is necessary because the target variable is highly skewed and contains many idle or near-zero throughput observations.

# %%
# Descriptive summary statistics
print("Descriptive statistics")
core_metrics = ['Throughput', 'SINR_UL', 'PRB', 'BLER']
summary_stats = master_df[core_metrics].describe()

# Add a row tracking the exact percentage of hard zero values in each column
zeros_pct = (master_df[core_metrics] == 0).sum() / len(master_df) * 100
summary_stats.loc['zeros_percentage'] = zeros_pct

print("\n=== DATASET STATISTICAL MATRIX ===")
print(summary_stats)
# Out:
# Descriptive statistics
#
# === DATASET STATISTICAL MATRIX ===
#                     Throughput       SINR_UL           PRB          BLER
# count             6.564000e+06  6.564000e+06  6.564000e+06  6.564000e+06
# mean              1.588067e+00 -1.197516e+01  1.144219e+01  2.954503e-02
# std               6.996522e+00  3.708634e+00  2.925637e+01  1.062844e-01
# min               0.000000e+00 -2.917920e+01  0.000000e+00  0.000000e+00
# 25%               0.000000e+00 -1.511456e+01  0.000000e+00  0.000000e+00
# 50%               0.000000e+00 -1.154012e+01  0.000000e+00  0.000000e+00
# 75%               1.040000e+00 -9.215209e+00  1.715000e+01  9.410000e-07
# max               6.751520e+02  3.447715e+00  5.000000e+02  9.946000e-01
# zeros_percentage  7.014980e+01  0.000000e+00  7.003917e+01  7.005186e+01

# %% [markdown]
# ### 5.1 Distribution Profiles of Core Wireless Metrics
#
# This figure shows the distributions of the main wireless variables used in the project: throughput, SINR, PRB, and BLER. The purpose is to understand the scale, skewness, and imbalance of the raw measurements before feature engineering and model training.
#
# Throughput and PRB are plotted with a logarithmic count axis because most observations are concentrated at low values, while only a smaller number of samples show high throughput or high resource allocation. This confirms that the regression target is highly skewed and that model performance should be interpreted using both raw-scale and log-scale metrics.

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 11))
fig.suptitle('Distribution Profiles of Core 5G Wireless Metrics (ACC Arena)', fontsize=16, fontweight='bold')

# Throughput Distribution
sns.histplot(data=master_df, x='Throughput', bins=50, ax=axes[0,0], color='royalblue', kde=False)
axes[0,0].set_title('User Throughput Distribution (Mbps)', fontsize=12)
axes[0,0].set_yscale('log') # Log scale prevents 0-value peaks from hiding everything else
axes[0,0].set_ylabel('Log Count')

# SINR Uplink Distribution
sns.histplot(data=master_df, x='SINR_UL', bins=50, ax=axes[0,1], color='forestgreen', kde=False)
axes[0,1].set_title('SINR Uplink Distribution (dB)', fontsize=12)
axes[0,1].set_ylabel('Count')

# Physical Resource Blocks (PRB) Distribution
sns.histplot(data=master_df, x='PRB', bins=30, ax=axes[1,0], color='darkorange', kde=False)
axes[1,0].set_title('PRB Allocation Profile', fontsize=12)
axes[1,0].set_yscale('log')
axes[1,0].set_ylabel('Log Count')

# Block Error Rate (BLER) Distribution
sns.histplot(data=master_df, x='BLER', bins=50, ax=axes[1,1], color='crimson', kde=False)
axes[1,1].set_title('Block Error Rate (BLER) Profile', fontsize=12)
axes[1,1].set_yscale('log')
axes[1,1].set_ylabel('Log Count')

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# The EDA confirms that the throughput target is highly skewed, with most observations concentrated at low values and a small number of high-throughput peaks. This motivates reporting both raw-scale metrics and log-scale metrics later in the notebook.
#
# The SINR distribution shows that users experience a range of radio-link qualities, while the BLER distribution indicates many low-error observations but also a long tail of higher-error cases. PRB is also highly skewed, which supports treating PRB carefully because it is closely related to radio-resource allocation and can dominate throughput prediction if used without caution.

# %% [markdown]
# ### 5.2 Correlation Analysis of Raw Wireless and Spatial Features
#
# This heatmap shows the pairwise linear correlation between the main raw wireless, spatial, and traffic-state variables. The goal is to identify redundant features, possible leakage-risk variables, and relationships that may influence throughput prediction.
#
# This analysis is only a first diagnostic because many wireless relationships are nonlinear. Therefore, low linear correlation does not necessarily mean that a feature is useless for Random Forest or Neural Network models.

# %%
# Select the numeric attributes we want to check for patterns
corr_features = ['X_meters', 'Y_meters', 'Throughput', 'SINR_UL', 'SINR_DL', 'PRB', 'RU', 'BLER', 'MobileState']
corr_matrix = master_df[corr_features].corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".3f", linewidths=0.5, vmin=-1, vmax=1)
plt.title('Correlation Matrix of Raw Wireless & Spatial Attributes', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# The correlation matrix shows that `SINR_UL` and `SINR_DL` are strongly correlated, which supports removing `SINR_DL` later to reduce redundancy. `PRB` has a noticeably higher correlation with throughput than most other raw variables, which is expected because PRB represents allocated radio resources. This also explains why PRB must be handled carefully: if the goal is to predict throughput before knowing the final scheduler allocation, PRB can act as a shortcut feature.
#
# Most other features show only weak linear correlation with throughput. This supports the use of nonlinear models such as Random Forest and Neural Networks, which can capture interactions between radio quality, resource load, user position, mobility, and traffic state.

# %% [markdown]
# ### 5.3 Radio Unit Connection Distribution
#
# This analysis checks how user samples are distributed across the available Radio Units (RUs). The goal is to understand whether the network load is balanced or whether some RUs serve many more user-time samples than others.
#
# Uneven RU connection counts are important because radio-unit congestion can affect throughput. If many users are connected to the same RU during the same time window, the available radio resources may be shared across more users. This motivates the later feature `RU_Current_Load`, which counts the number of users connected to the same RU at each timestamp.

# %%
# 1. Count exactly how many records are connected to each individual Radio Unit
ru_counts = master_df['RU'].value_counts().sort_index()
ru_percentages = master_df['RU'].value_counts(normalize=True).sort_index() * 100

print("\n=== RADIO UNIT CONNECTION DISTRIBUTION ===")
for ru_id in ru_counts.index:
    print(f"📡 Radio Unit {ru_id}: {ru_counts[ru_id]:,} connections ({ru_percentages[ru_id]:.2f}%)")

# 2. Visualize the categorical load balancing using a Bar Chart
plt.figure(figsize=(10, 5))
sns.countplot(data=master_df, x='RU', palette='viridis')
plt.title('Network Load Balancing: Connection Counts per Radio Unit (RU)', fontsize=14, fontweight='bold')
plt.xlabel('Radio Unit (RU) ID Index')
plt.ylabel('Total Allocated Sample Points')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# === RADIO UNIT CONNECTION DISTRIBUTION ===
# 📡 Radio Unit 1: 51,527 connections (0.78%)
# 📡 Radio Unit 2: 170,848 connections (2.60%)
# 📡 Radio Unit 3: 239,363 connections (3.65%)
# 📡 Radio Unit 4: 43,746 connections (0.67%)
# 📡 Radio Unit 5: 92,134 connections (1.40%)
# 📡 Radio Unit 6: 290,885 connections (4.43%)
# 📡 Radio Unit 7: 59,642 connections (0.91%)
# 📡 Radio Unit 8: 29,800 connections (0.45%)
# 📡 Radio Unit 9: 276,762 connections (4.22%)
# 📡 Radio Unit 10: 22,081 connections (0.34%)
# 📡 Radio Unit 11: 154,019 connections (2.35%)
# 📡 Radio Unit 12: 226,799 connections (3.46%)
# 📡 Radio Unit 13: 70,583 connections (1.08%)
# 📡 Radio Unit 14: 40,604 connections (0.62%)
# 📡 Radio Unit 15: 289,208 connections (4.41%)
# 📡 Radio Unit 16: 93,250 connections (1.42%)
# 📡 Radio Unit 17: 44,586 connections (0.68%)
# 📡 Radio Unit 18: 303,971 connections (4.63%)
# 📡 Radio Unit 19: 212,999 connections (3.24%)
# 📡 Radio Unit 20: 83,778 connections (1.28%)
# 📡 Radio Unit 21: 191,770 connections (2.92%)
# 📡 Radio Unit 22: 319,094 connections (4.86%)
# 📡 Radio Unit 23: 115,318 connections (1.76%)
# 📡 Radio Unit 24: 283,788 connections (4.32%)
# 📡 Radio Unit 25: 155,446 connections (2.37%)
# 📡 Radio Unit 26: 176,772 connections (2.69%)
# 📡 Radio Unit 27: 165,515 connections (2.52%)
# 📡 Radio Unit 28: 233,749 connections (3.56%)
# 📡 Radio Unit 29: 216,210 connections (3.29%)
# 📡 Radio Unit 30: 360,476 connections (5.49%)
# 📡 Radio Unit 31: 701,548 connections (10.69%)
# 📡 Radio Unit 32: 360,825 connections (5.50%)
# 📡 Radio Unit 33: 486,904 connections (7.42%)

# %% [markdown]
# The plot shows that the number of allocated samples is not uniform across radio units. Some RUs serve substantially more samples than others, suggesting that network load is spatially uneven in the ACC Arena scenario. This supports including radio-unit load as an engineered feature for throughput prediction.

# %% [markdown]
# ### 5.4 Traffic-Class Composition and Throughput Behaviour
#
# The `MobileState` variable describes the user traffic/application profile. This analysis maps the numeric traffic-state codes into readable labels and compares two aspects of the dataset:
#
# 1. how many samples belong to each traffic class;
# 2. the average throughput observed for each traffic class.
#
# This is important because the dataset is strongly imbalanced. Idle users dominate the sample volume, while active traffic classes such as Constant Rate, Video, Gaming, and HTTP appear less frequently but have much higher throughput values.

# %%
# 1. Map numeric MobileState codes to traffic-class labels
traffic_labels = {
    0: '0: Off',
    1: '1: Idle',
    2: '2: Constant Rate',
    3: '3: Video',
    4: '4: Gaming',
    5: '5: HTTP'
}
master_df['Traffic_Label'] = master_df['MobileState'].map(traffic_labels)

# 2. Print absolute composition metrics
traffic_counts = master_df['Traffic_Label'].value_counts().sort_index()
traffic_pct = master_df['Traffic_Label'].value_counts(normalize=True).sort_index() * 100

print("\n=== TRAFFIC MIX COMPOSITION MATRIX ===")
for label in traffic_counts.index:
    print(f" {label:<18} -> {traffic_counts[label]:>9,} rows ({traffic_pct[label]:.2f}%)")

# 3. Visualize Behavior: How does Traffic Class change Throughput?
plt.figure(figsize=(14, 6))

# Subplot 1: Volume of rows per traffic type
plt.subplot(1, 2, 1)
sns.countplot(data=master_df, x='Traffic_Label', palette='Set2', order=sorted(traffic_labels.values()))
plt.title('Dataset Volume by Traffic Class', fontsize=12, fontweight='bold')
plt.xlabel('Application Profile')
plt.ylabel('Total Sample Count')
plt.xticks(rotation=30, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Subplot 2: Average Throughput per traffic type
plt.subplot(1, 2, 2)
sns.barplot(data=master_df, x='Traffic_Label', y='Throughput', palette='Set2', order=sorted(traffic_labels.values()), errorbar=None)
plt.title('Mean Throughput by Traffic Class', fontsize=12, fontweight='bold')
plt.xlabel('Application Profile')
plt.ylabel('Average Throughput (Mbps)')
plt.xticks(rotation=30, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# === TRAFFIC MIX COMPOSITION MATRIX ===
#  0: Off             ->    11,444 rows (0.17%)
#  1: Idle            -> 4,595,546 rows (70.01%)
#  2: Constant Rate   -> 1,041,493 rows (15.87%)
#  3: Video           ->    59,221 rows (0.90%)
#  4: Gaming          ->    41,712 rows (0.64%)
#  5: HTTP            ->   814,584 rows (12.41%)

# %% [markdown]
# The traffic-class distribution confirms that the dataset is dominated by idle observations. This explains why throughput prediction is challenging: a model must learn both the frequent idle or near-zero-throughput cases and the less frequent active high-throughput cases.
#
# The mean-throughput plot shows that active traffic classes have substantially higher average throughput than Off or Idle states. This supports using `MobileState` as a contextual feature through one-hot encoding, allowing the models to learn traffic-specific throughput patterns.

# %% [markdown]
# ## 6. Feature Engineering
#
# This section converts the aggregated 60-second user-level table into a set of physically meaningful predictors for throughput regression. The engineered features are designed around four domains:
#
# 1. **Radio and link quality:** SINR and BLER are used to describe the quality of the wireless link. SINR is converted from dB to a linear scale and combined with BLER to create a robust effective-signal feature.
# 2. **Infrastructure congestion:** `RU_Current_Load` counts how many users are connected to the same radio unit at the same timestamp.
# 3. **Mobility and local crowding:** User movement is represented using position changes, and the Team 9 feature is implemented by counting nearby users within multiple X-meter radii.
# 4. **Application behavior:** `MobileState` is one-hot encoded so the models can learn different throughput patterns for different traffic states.
#
# The final clean feature set is designed to avoid obvious leakage. PRB and `Resource_Efficiency` are created and inspected because PRB is part of the project data, but they are treated as leakage-risk features rather than included blindly in the main clean models.

# %% [markdown]
# ### 6.1 Multi-Domain Feature Engineering Function
#
# The following function creates the main engineered dataframe used by the models. It performs four main operations:
#
# - removes highly redundant radio information by dropping `SINR_DL`, which was found to be strongly correlated with `SINR_UL`;
# - creates a robust effective-signal feature from high SINR and low BLER conditions;
# - computes radio-unit load and movement-related features;
# - calculates the Team 9 crowd-density features at 2m, 5m, and 10m.
#
# Although `Resource_Efficiency` is created for analysis, it is treated as a leakage-risk feature because it depends on PRB, which is closely tied to scheduler resource allocation and therefore strongly related to throughput.

# %%
def engineer_acc_arena_features(df):
    """
    Executes advanced multi-domain feature engineering for the ACC Arena dataset.
    Optimized for memory efficiency and handles dynamic user dropouts safely.
    """
    print("Initiating Advanced Feature Engineering Pipeline...")
    feat_df = df.copy()

    # Identify correct time column based on our previous timeline fixes
    time_col = 'Timestamp_Sec' if 'Timestamp_Sec' in feat_df.columns else 'Timestamp'

    # CRITICAL: Sort by User_ID first to ensure perfect trajectory math
    feat_df = feat_df.sort_values(by=['User_ID', time_col]).reset_index(drop=True)

    # ----------------------------------------------------
    # DOMAIN 1: RADIO & LINK PHYSICS
    # ----------------------------------------------------
    print(" Engineering Radio Domain features...")
    print(" Regressing the max throughput...")

    # >0.9 linearity with SINR_UL
    feat_df.drop(columns=["SINR_DL"], inplace=True)

    # 4. Generate the Physics-Informed Robust Signal Feature
    feat_df['SINR_Linear_q90'] = (10 ** (feat_df['SINR_UL_q90'] / 10.0)).astype(np.float32)
    
    feat_df['Effective_Signal_Robust'] = np.clip(
        feat_df['SINR_Linear_q90'] / (feat_df['BLER_q10'] + 1e-4), 0, 1e6
    ).astype(np.float32)
    
    feat_df['Log_Effective_Signal_Robust'] = np.log1p(
        feat_df['Effective_Signal_Robust']
    ).astype(np.float32)

    # ----------------------------------------------------
    # DOMAIN 2: INFRASTRUCTURE CONGESTION
    # ----------------------------------------------------
    print(" Calculating Real-Time Radio Unit Load...")
    feat_df['RU_Current_Load'] = feat_df.groupby([time_col, 'RU'])['User_ID'].transform('count').astype(np.int16)

    # ----------------------------------------------------
    # DOMAIN 3: TEMPORAL & SPATIAL MOBILITY
    # ----------------------------------------------------
    print(" Computing Kinematic Vectors...")
  
    
    user_groups = feat_df.groupby('User_ID')
    feat_df['Delta_X'] = user_groups['X_meters'].diff().fillna(0).astype(np.float32)
    feat_df['Delta_Y'] = user_groups['Y_meters'].diff().fillna(0).astype(np.float32)
    feat_df['Velocity'] = np.sqrt(feat_df['Delta_X']**2 + feat_df['Delta_Y']**2).astype(np.float32)

    print(" Vectorizing Multi-Scale Local Crowd Density (cKDTree)...")
    radii = [2.0, 5.0, 10.0]
    density_results = {r: np.zeros(len(feat_df), dtype=np.int16) for r in radii}

    grouped_time = feat_df.groupby(time_col)
    
    # cKDTree easily handles missing users without crashing
    for t, group in tqdm(grouped_time, desc="Mapping Densities"):
        coords = group[['X_meters', 'Y_meters']].values
        tree = cKDTree(coords)
        for r in radii:
            counts = np.array([len(neighbors) - 1 for neighbors in tree.query_ball_point(coords, r)])
            density_results[r][group.index] = counts

    feat_df['Crowd_Density_2m'] = density_results[2.0]
    feat_df['Crowd_Density_5m'] = density_results[5.0]
    feat_df['Crowd_Density_10m'] = density_results[10.0]

    # ----------------------------------------------------
    # DOMAIN 4: APPLICATION BEHAVIOR
    # ----------------------------------------------------
    print(" Decoding Application States...")
    state_dummies = pd.get_dummies(feat_df['MobileState'], prefix='State').astype(np.int8)
    feat_df = pd.concat([feat_df, state_dummies], axis=1)

    feat_df['Resource_Efficiency'] = (feat_df['PRB'] * (feat_df['MobileState'] != 1)).astype(np.float32)

    # ----------------------------------------------------
    # MEMORY & INTEGRITY AUDIT
    # ----------------------------------------------------
    print("\n Finalizing Memory Cleanup Audit...")
    feat_df.drop(columns=['Delta_X', 'Delta_Y'], inplace=True)

    final_mem = feat_df.memory_usage(deep=True).sum() / (1024 ** 2)
    print(f" Engineering Complete! Dataframe Shape: {feat_df.shape}")
    print(f" Memory Footprint: {final_mem:.2f} MB")

    return feat_df

# %%
if os.path.exists(cached_feat):
    print("Loading processed cache...")
    arena_featured_df = pd.read_parquet(cached_feat)
elif os.path.exists(ds_feat):
    print("Loading processed from input ds...")
    arena_featured_df = pd.read_parquet(ds_feat)
else:
    print("No checkpoint found. Running feature engineering...")
    arena_featured_df = engineer_acc_arena_features(master_df)
    arena_featured_df.to_parquet(cached_feat, index=False)
    print("Checkpoint saved.")
# Out:
# Loading processed from input ds...

# %%
arena_featured_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6564000 entries, 0 to 6563999
# Data columns (total 31 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Timestamp_Sec                int64
#  1   User_ID                      int32
#  2   Latitude                     float32
#  3   Longitude                    float32
#  4   Altitude                     float32
#  5   X_meters                     float32
#  6   Y_meters                     float32
#  7   SINR_UL                      float32
#  8   BLER                         float32
#  9   RU                           int8
#  10  MobileState                  int8
#  11  Throughput                   float32
#  12  PRB                          float32
#  13  SINR_UL_q90                  float32
#  14  BLER_q10                     float32
#  15  Traffic_Label                object
#  16  SINR_Linear_q90              float32
#  17  Effective_Signal_Robust      float32
#  18  Log_Effective_Signal_Robust  float32
#  19  RU_Current_Load              int16
#  20  Velocity                     float32
#  21  Crowd_Density_2m             int16
#  22  Crowd_Density_5m             int16
#  23  Crowd_Density_10m            int16
#  24  State_0                      int8
#  25  State_1                      int8
#  26  State_2                      int8
#  27  State_3                      int8
#  28  State_4                      int8
#  29  State_5                      int8
#  30  Resource_Efficiency          float32
# dtypes: float32(16), int16(4), int32(1), int64(1), int8(8), object(1)
# memory usage: 626.0+ MB

# %%
arena_featured_df.head(30)
# Out:
#     Timestamp_Sec  User_ID   Latitude  Longitude  Altitude  X_meters  \
# 0               0        0  53.395084  -2.992707  3.581009       0.0
# 1              60        0  53.395084  -2.992707  3.581009       0.0
# 2             120        0  53.395084  -2.992707  3.581009       0.0
# 3             180        0  53.395084  -2.992707  3.581009       0.0
# 4             240        0  53.395084  -2.992707  3.581009       0.0
# 5             300        0  53.395084  -2.992707  3.581009       0.0
# 6             360        0  53.395084  -2.992707  3.581009       0.0
# 7             420        0  53.395084  -2.992707  3.581009       0.0
# 8             480        0  53.395084  -2.992707  3.581009       0.0
# 9             540        0  53.395084  -2.992707  3.581009       0.0
# 10            600        0  53.395084  -2.992707  3.581009       0.0
# 11            660        0  53.395084  -2.992707  3.581009       0.0
# 12            720        0  53.395084  -2.992707  3.581009       0.0
# 13            780        0  53.395084  -2.992707  3.581009       0.0
# 14            840        0  53.395084  -2.992707  3.581009       0.0
# 15            900        0  53.395084  -2.992707  3.581009       0.0
# 16            960        0  53.395084  -2.992707  3.581009       0.0
# 17           1020        0  53.395084  -2.992707  3.581009       0.0
# 18           1080        0  53.395084  -2.992707  3.581009       0.0
# 19           1140        0  53.395084  -2.992707  3.581009       0.0
# 20           1200        0  53.395084  -2.992707  3.581009       0.0
# 21           1260        0  53.395084  -2.992707  3.581009       0.0
# 22           1320        0  53.395084  -2.992707  3.581009       0.0
# 23           1380        0  53.395084  -2.992707  3.581009       0.0
# 24           1440        0  53.395084  -2.992707  3.581009       0.0
# 25           1500        0  53.395084  -2.992707  3.581009       0.0
# 26           1560        0  53.395084  -2.992707  3.581009       0.0
# 27           1620        0  53.395084  -2.992707  3.581009       0.0
# 28           1680        0  53.395084  -2.992707  3.581009       0.0
# 29           1740        0  53.395084  -2.992707  3.581009       0.0
#
#     Y_meters    SINR_UL      BLER  RU  ...  Crowd_Density_2m  \
# 0        0.0 -14.772825  0.813364  26  ...                35
# 1        0.0 -16.963371  0.743953  26  ...                35
# 2        0.0 -14.323143  0.576724  26  ...                35
# 3        0.0 -10.458859  0.219680  26  ...                35
# 4        0.0  -9.672252  0.204938  26  ...                35
# 5        0.0 -10.464019  0.189375  26  ...                35
# 6        0.0 -10.004877  0.165452  26  ...                35
# 7        0.0 -10.476074  0.255898  26  ...                35
# 8        0.0 -10.385905  0.220332  26  ...                35
# 9        0.0 -10.951180  0.182759  26  ...                35
# 10       0.0 -10.602502  0.189272  26  ...                35
# 11       0.0 -10.927042  0.116775  26  ...                35
# 12       0.0  -9.623416  0.185191  26  ...                35
# 13       0.0 -10.661351  0.108189  26  ...                35
# 14       0.0 -18.304892  0.734142  26  ...                35
# 15       0.0 -17.267597  0.750064  26  ...                35
# 16       0.0 -16.647642  0.899986  26  ...                35
# 17       0.0 -17.391594  0.806581  26  ...                35
# 18       0.0 -18.270884  0.892728  26  ...                35
# 19       0.0 -10.360932  0.182835  26  ...                35
# 20       0.0 -10.440495  0.388315  26  ...                35
# 21       0.0 -10.188288  0.179698  26  ...                35
# 22       0.0 -11.039919  0.245101  26  ...                35
# 23       0.0 -10.198119  0.302918  26  ...                35
# 24       0.0 -10.549674  0.245465  26  ...                35
# 25       0.0 -10.832874  0.233868  26  ...                35
# 26       0.0 -10.272258  0.258562  26  ...                35
# 27       0.0 -11.043261  0.122157  26  ...                35
# 28       0.0 -15.736164  0.756126   9  ...                35
# 29       0.0 -16.881868  0.734280   9  ...                35
#
#     Crowd_Density_5m  Crowd_Density_10m  State_0  State_1 State_2  State_3  \
# 0                 35                 46        0        0       1        0
# 1                 35                 46        0        0       1        0
# 2                 35                 46        0        0       1        0
# 3                 35                 46        0        0       1        0
# 4                 35                 46        0        0       1        0
# 5                 35                 46        0        0       1        0
# 6                 35                 46        0        0       1        0
# 7                 35                 46        0        0       1        0
# 8                 35                 46        0        0       1        0
# 9                 35                 46        0        0       1        0
# 10                35                 46        0        0       1        0
# 11                35                 46        0        0       1        0
# 12                35                 46        0        0       1        0
# 13                35                 46        0        0       1        0
# 14                35                 46        0        0       1        0
# 15                35                 46        0        0       1        0
# 16                35                 46        0        0       1        0
# 17                35                 46        0        0       1        0
# 18                35                 46        0        0       1        0
# 19                35                 46        0        0       1        0
# 20                35                 46        0        0       1        0
# 21                35                 46        0        0       1        0
# 22                35                 46        0        0       1        0
# 23                35                 46        0        0       1        0
# 24                35                 46        0        0       1        0
# 25                35                 46        0        0       1        0
# 26                35                 46        0        0       1        0
# 27                35                 46        0        0       1        0
# 28                35                 46        0        0       1        0
# 29                35                 46        0        0       1        0
#
#     State_4  State_5  Resource_Efficiency
# 0         0        0            33.700001
# 1         0        0            37.150002
# 2         0        0            34.299999
# 3         0        0            33.299999
# 4         0        0            35.150002
# 5         0        0            29.450001
# 6         0        0            34.000000
# 7         0        0            37.000000
# 8         0        0            36.750000
# 9         0        0            36.299999
# 10        0        0            35.150002
# 11        0        0            31.299999
# 12        0        0            34.000000
# 13        0        0            36.150002
# 14        0        0            31.299999
# 15        0        0            30.750000
# 16        0        0            29.000000
# 17        0        0            32.750000
# 18        0        0            27.150000
# 19        0        0            30.150000
# 20        0        0            26.000000
# 21        0        0            32.200001
# 22        0        0            30.299999
# 23        0        0            29.600000
# 24        0        0            32.150002
# 25        0        0            30.450001
# 26        0        0            31.750000
# 27        0        0            27.150000
# 28        0        0            26.000000
# 29        0        0            22.150000
#
# [30 rows x 31 columns]

# %% [markdown]
# ### 6.2 Radio-Quality Sanity Check
#
# Before training the models, the engineered radio-quality features are visually checked against throughput for active users only. This confirms whether the relationships are physically reasonable.
#
# In wireless systems, higher SINR usually indicates better signal quality, while lower BLER indicates fewer transmission errors. Therefore, higher throughput is expected when SINR is high and BLER is low. The `Log_Effective_Signal_Robust` feature combines these effects into a smoother single indicator of link quality.

# %%
# ═══════════════════════════════════════════════════════════════
#  DIAGNOSTICS (visual only)
# ════════════════════════════════════════════════════════════════
active_df = arena_featured_df[arena_featured_df['Throughput'] > 0].copy()

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].scatter(active_df['SINR_UL_q90'], active_df['Throughput'], alpha=0.1, s=1)
axes[0].set_xlabel('SINR_UL_q90 (dB)'); axes[0].set_ylabel('Throughput (Mbps)')
axes[0].set_title('SINR_UL_q90 vs Throughput')

axes[1].scatter(active_df['BLER_q10'], active_df['Throughput'], alpha=0.1, s=1)
axes[1].set_xlabel('BLER_q10'); axes[1].set_ylabel('Throughput (Mbps)')
axes[1].set_title('BLER_q10 vs Throughput')

axes[2].scatter(active_df['Log_Effective_Signal_Robust'], active_df['Throughput'], alpha=0.1, s=1)
axes[2].set_xlabel('Log_Effective_Signal_Robust'); axes[2].set_ylabel('Throughput (Mbps)')
axes[2].set_title('Log_Effective_Signal_Robust vs Throughput')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.3 Physical Validity Filtering
#
# This step removes physically invalid or unrealistic rows before modeling. Throughput must be non-negative, BLER must remain within the valid probability range [0, 1], and SINR values are restricted to a realistic radio range.
#
# The additional spike inspection checks whether very high throughput values are concentrated in specific radio units or appear as suspicious artifacts. This helps verify that extreme values are part of the simulated network behavior rather than corrupted rows.

# %%
# ============================================================
# Hard physical sanity filters
# ============================================================
before = len(arena_featured_df)

arena_featured_df = arena_featured_df[
    (arena_featured_df['Throughput'] >= 0) &
    (arena_featured_df['BLER'].between(0, 1)) &
    (arena_featured_df['BLER_q10'].between(0, 1)) &
    (arena_featured_df['SINR_UL'].between(-40, 30)) &
    (arena_featured_df['SINR_UL_q90'].between(-40, 30))
].copy()

after = len(arena_featured_df)
print(f"Removed {before - after:,} physically invalid rows")

spike = arena_featured_df[arena_featured_df['Throughput'] > 500]
print(spike['Throughput'].value_counts().head(20))

display(
    spike.groupby(['RU'])['Throughput']
         .agg(['count', 'mean', 'min', 'max'])
         .sort_values('count', ascending=False)
         .head(20)
)
# Out:
# Removed 0 physically invalid rows
# Throughput
# 515.056030    124
# 514.104004     66
# 539.070374     26
# 538.849609     12
# 513.935974      5
# 538.118408      4
# 673.900818      4
# 537.897583      2
# 529.910400      1
# 675.151978      1
# Name: count, dtype: int64
#     count        mean         min         max
# RU
# 10     56  520.356079  514.104004  539.070374
# 1      38  518.272217  513.935974  539.070374
# 8      31  520.857971  513.935974  539.070374
# 13     22  518.017761  514.104004  539.070374
# 14     21  539.144287  514.104004  675.151978
# 4      17  534.919312  514.104004  673.900818
# 20     13  516.537109  514.104004  539.070374
# 17     11  518.954163  513.935974  539.070374
# 16     10  530.654907  514.104004  673.900818
# 7       8  514.817993  514.104004  515.056030
# 23      6  518.862976  514.104004  538.849609
# 5       5  519.668518  514.104004  539.070374
# 24      3  522.426147  514.104004  538.118408
# 25      2  514.495972  513.935974  515.056030
# 2       1  514.104004  514.104004  514.104004
# 15      1  515.056030  515.056030  515.056030

# %% [markdown]
# ### 6.4 Radio-Throughput Consistency Flags
#
# This optional diagnostic labels unusual active-user cases, such as high throughput despite weak effective signal or low throughput despite strong effective signal. These cases are not automatically removed, because they may reflect scheduler effects, congestion, or traffic-state behavior rather than data errors.
#
# The purpose is to identify edge cases for interpretation, not to filter the dataset aggressively.

# %%
high_tp = active_df['Throughput'] >= active_df['Throughput'].quantile(0.99)
low_tp = active_df['Throughput'] <= active_df['Throughput'].quantile(0.10)

high_signal = active_df['Log_Effective_Signal_Robust'] >= active_df['Log_Effective_Signal_Robust'].quantile(0.90)
low_signal  = active_df['Log_Effective_Signal_Robust'] <= active_df['Log_Effective_Signal_Robust'].quantile(0.10)

active_df['Anomaly_Type'] = 'normal'
active_df.loc[high_tp & low_signal, 'Anomaly_Type'] = 'high_tp_bad_signal'
active_df.loc[low_tp & high_signal, 'Anomaly_Type'] = 'low_tp_good_signal'

# %% [markdown]
# ### 6.5 Final Clean Feature Set
#
# This cell defines the main non-leaky feature set used across the core models. The features include user position, radio quality, radio-unit load, movement, effective signal quality, the selected 5m crowd-density feature, and one-hot encoded traffic-state variables.
#
# Crowd density was computed at 2m, 5m, and 10m, but only the 5m feature is used in the final base feature set because the three density features are strongly correlated and 5m provided a good balance between local detail and stability.
#
# Although `Crowd_Density_5m` is computed from user positions, it is assigned to the RU-side/network-side feature view in the VFL experiments. This is because the feature depends on neighborhood-level information about multiple users around the target device, rather than only the target terminal's own local state.

# %%
# ============================================================
# Feature definition: non-leaky, non-redundant
# ============================================================
target = 'Throughput'

crowd_density = ['Crowd_Density_2m','Crowd_Density_5m','Crowd_Density_10m']

state_cols = [c for c in arena_featured_df.columns if c.startswith('State_')]

base_feats = [
    'X_meters', 'Y_meters',
    'SINR_UL','SINR_UL_q90', 'BLER','BLER_q10', 
    'RU_Current_Load', 'Velocity', 'Log_Effective_Signal_Robust'
] + [crowd_density[1]] + state_cols

# Keep only columns that actually exist
base_feats = [c for c in base_feats if c in arena_featured_df.columns]

# Safety check: drop globally constant / near-constant features
def remove_constant_features(df, cols, threshold=1e-6):
    kept, dropped = [], []
    for c in cols:
        if c in df.columns and df[c].std(skipna=True) > threshold:
            kept.append(c)
        else:
            dropped.append(c)
    if dropped:
        print("Dropped near-constant features:", dropped)
    return kept

base_feats = remove_constant_features(arena_featured_df, base_feats)

# %% [markdown]
# ### 6.6 Removing Redundant or Unstable Features
#
# The raw `Effective_Signal_Robust` value can become extremely large when BLER is close to zero. Since the logarithmic version is smoother and more stable, the raw version is removed from the final dataframe.
#
# The movement feature is also checked to ensure that it is not mostly missing or constant. Features with no meaningful variation do not help the model and can make the feature set unnecessarily noisy.

# %%
arena_featured_df.drop(columns=['Effective_Signal_Robust'], inplace=True) 
if not (arena_featured_df['Velocity'].notna().mean() > 0.95 and arena_featured_df['Velocity'].nunique() > 1):
    print("Velocity not added to features (constant or mostly NaN).")
    arena_featured_df.drop(columns=['Velocity'], inplace=True)

# %% [markdown]
# ### 6.7 Dynamic Feature Group
#
# The dynamic feature group contains variables expected to change over time, such as SINR, BLER, radio-unit load, user position, movement, effective signal quality, and local crowd density.
#
# This group is later used by the neural-network model so that time-varying behavior can be handled separately from static or categorical features.

# %%
# manual separation dynamics and static, should be based on global activity dynamic
dynamic_cols = [
    'SINR_UL',
    'BLER',
    'SINR_UL_q90',
    'BLER_q10',
    'Log_Effective_Signal_Robust',
    'RU_Current_Load',
    'X_meters',
    'Y_meters',
    'Velocity',
] + [crowd_density[1]]

# %% [markdown]
# ### 6.8 Dynamic Feature Activity Check
#
# The candidate dynamic features have different physical scales, so they are first normalized between 0 and 1 before comparing their variability. After normalization, we compute the average within-user standard deviation for each feature.
#
# Features with higher normalized standard deviation contain more temporal activity and are more useful for models that rely on changing user/network conditions. Features with very low activity provide limited temporal information and may be less useful for the dynamic branch of the neural-network pipeline.

# %%
# Step 1: Create a temporary dataframe scaled between 0 and 1 for fair comparison
df_scaled = arena_featured_df[dynamic_cols].copy()
for col in dynamic_cols:
    col_min = df_scaled[col].min()
    col_max = df_scaled[col].max()
    if col_max - col_min > 0:
        df_scaled[col] = (df_scaled[col] - col_min) / (col_max - col_min)

# Step 2: Compute average activity on the normalized scale
# Using the User_ID from the original master dataframe to group
activity = (
    df_scaled.groupby(arena_featured_df["User_ID"])
    .std()      # Variance relative to each feature's own min/max limits
    .mean()     # Average across users
    .sort_values(ascending=False)
)

# # Step 3: Render the corrected true activity distribution
plt.figure(figsize=(16, 8))
activity.plot(kind='bar', title='True Normalized Feature Activity (STD across User)', color='teal', rot=90)
plt.xlabel('Feature')
plt.ylabel('Normalized Standard Deviation (0.0 to 1.0 Scale)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# The activity check shows that `RU_Current_Load`, `SINR_UL`, `Log_Effective_Signal_Robust`, and `SINR_UL_q90` have the strongest temporal variation. This supports keeping radio-load and radio-quality features in the dynamic feature group.
#
# In contrast, position, velocity, and local crowd density show lower average variation for individual users. These features may still provide useful context, but they contribute less temporal movement than the radio-quality and load features.

# %% [markdown]
# ### 6.9 Dynamic and Static Feature Decomposition
#
# For the neural-network models, the feature set is separated into dynamic and static groups. Dynamic features are expected to vary over time, such as SINR, BLER, radio-unit load, user position, movement, and crowd density. Static or contextual features, such as traffic-state one-hot columns, are handled separately as additional context.
#
# To avoid passing uninformative variables into the temporal branch, each candidate dynamic feature is checked using its mean per-user standard deviation. A feature is retained as dynamic only if it shows meaningful variation over time. This helps ensure that the sequence-based model receives features that actually change across each user's timeline.

# %% [markdown]
# This cell finalizes the dynamic and static feature groups. Dynamic features are retained only if they are present in the clean feature set and show sufficient temporal activity. Static features are taken from the one-hot encoded traffic-state columns.
#
# These feature groups are later used by the neural-network models to separate time-varying behavior from contextual information.

# %%
dyn_threshold = 1e-4
dynamic_cols = [c for c in dynamic_cols if c in base_feats and activity[c] > dyn_threshold]

static_cols = [c for c in state_cols if c in base_feats]

print("BASE_FEATS:", base_feats)
print("dynamic_cols:", dynamic_cols)
print("static_cols:", static_cols)
# Out:
# BASE_FEATS: ['X_meters', 'Y_meters', 'SINR_UL', 'SINR_UL_q90', 'BLER', 'BLER_q10', 'RU_Current_Load', 'Velocity', 'Log_Effective_Signal_Robust', 'Crowd_Density_5m', 'State_0', 'State_1', 'State_2', 'State_3', 'State_4', 'State_5']
# dynamic_cols: ['SINR_UL', 'BLER', 'SINR_UL_q90', 'BLER_q10', 'Log_Effective_Signal_Robust', 'RU_Current_Load', 'X_meters', 'Y_meters', 'Velocity', 'Crowd_Density_5m']
# static_cols: ['State_0', 'State_1', 'State_2', 'State_3', 'State_4', 'State_5']

# %% [markdown]
# ### 6.10 Optional Lagged Feature Experiment
#
# Lagged features were tested to give non-sequential models, such as Random Forest, limited memory of previous time steps. The most active dynamic features were selected as lag candidates.
#
# However, lagged features increased memory usage and did not provide enough improvement to justify the additional computational cost. Therefore, lagged features are treated as an optional experiment and are not part of the final clean feature set unless `use_lag` is enabled.

# %%
use_lag = False

# %%
# ────────────────────────────────────────────────────────────────
# CLEAN FEATURE DEFINITIONS
# ────────────────────────────────────────────────────────────────
df = arena_featured_df.copy()
lagged_feat = activity.head(4).index.tolist()
newly_generated_lag_cols = []

if use_lag:
  LAGS = [5, 10]
  user_ids = df['User_ID'].values
  print("generating new lagged features...")
  # Generate lagged features and update TRAIN_FEATS with their names
  # for col in train_feats_base:
  for col in lagged_feat:
      arr = df[col]
      for lag in LAGS:
        new_col = f'{col}_lag{lag}'
        shifted = np.full(len(df), np.nan, dtype=np.float32)
        shifted[lag:] = arr[:-lag]
        invalid = np.zeros(len(df), dtype=bool)
        invalid[lag:] = (user_ids[lag:] != user_ids[:-lag])
        shifted[invalid] = np.nan
        df[new_col] = shifted
        newly_generated_lag_cols.append(new_col)
    
    # Quick check: manual shift just to check correlation with your target variable
  for col in newly_generated_lag_cols:
    corr = df[col].corr(df[target])
    print(f"{col} Lag Corr with Target: {corr:.4f}")

# %% [markdown]
# ### 6.11 Active vs Idle Throughput Target
#
# The throughput target is highly zero-heavy because many users are idle or have no measurable throughput during a given time window. To quantify this imbalance, a binary variable `Has_Throughput` is created.
#
# `Has_Throughput = 1` means the user has positive throughput in that 60-second window, while `Has_Throughput = 0` represents an idle or zero-throughput observation.
#
# This statistic helps explain why raw-scale throughput regression is difficult and why log-scale metrics are also reported in the final evaluation.

# %%
df['Has_Throughput'] = (df[target] > 0).astype(np.int8)
active_ratio = df['Has_Throughput'].mean()
print(f"Active (throughput > 0): {active_ratio*100:.1f}%  |  Idle: {(1-active_ratio)*100:.1f}%")
# Out:
# Active (throughput > 0): 29.9%  |  Idle: 70.1%

# %% [markdown]
# ## 7. User-Level Data Split and Modeling Setup
#
# The dataset is split by **User_ID** rather than by random rows. This is important because each user has a time series of observations; random row splitting could place the same user's samples in both training and testing, making the evaluation overly optimistic.
#
# For the full ACC Arena setup, users with IDs below 10,000 are used for training and validation, while users with IDs from 10,000 onward are kept as the final unseen test set. Inside the train/validation group, users are randomly shuffled and split into training and validation users.
#
# The final notebook uses the natural class distribution rather than undersampling for the main LSTM/MLP pipeline. This keeps the training setup realistic because idle users dominate the original dataset.

# %%
def train_test_split(df, test_id_start=10000, val_frac=0.20, random_seed=42, is_undersampling=False):
    if (max_user_id == 1499):
        test_id_start = 1200
    # 1. Split out the finall unseen test users
    test_df = df[df['User_ID'] >= test_id_start].copy()
    train_val_df = df[df['User_ID'] < test_id_start].copy()
    
    # 2. Get unique users from train_val and shuffle
    unique_users = train_val_df['User_ID'].unique().tolist()
    random.seed(random_seed)
    random.shuffle(unique_users)
    
    val_size = int(len(unique_users) * val_frac)
    val_users = set(unique_users[:val_size])
    train_users = set(unique_users[val_size:])

    # 3. Create training and validation DataFrames
    train_df = train_val_df[train_val_df['User_ID'].isin(train_users)].copy()
    val_df = train_val_df[train_val_df['User_ID'].isin(val_users)].copy()

    if is_undersampling:
        print("2. Undersampling the Training Data...")
        # Separate the classes INSIDE the training set only
        idle_rows = train_df[train_df['Has_Throughput'] == 0]
        active_rows = train_df[train_df['Has_Throughput'] != 0]
        
        # Undersample the Idle class to perfectly match the active traffic volume (1:1 balance)
        sampled_idle = idle_rows.sample(n=len(active_rows), random_state=random_seed)
        
        # Combine and Shuffle to create the final balanced training set
        train_df = pd.concat([active_rows, sampled_idle], axis=0).sample(frac=1, random_state=random_seed).reset_index(drop=True)
        print(f"✅ New Balanced Training Shape: {train_df.shape}")
        print(f"✅ Untouched Validation Shape: {val_df.shape}")

    print(f"  Test users:   {len(test_df['User_ID'].unique())} → {len(test_df):,} rows")
    print(f"  Train users:  {len(train_users)} → {len(train_df):,} rows")
    print(f"  Val users:    {len(val_users)}   → {len(val_df):,} rows")
    return train_df, val_df, test_df

# %%
print("\n=== TRAIN, VAL/ TEST SPLIT ===")

# Map numeric MobileState codes to traffic-class labels
train_df, val_df, test_df = train_test_split(df, is_undersampling=False)
# Out:
# === TRAIN, VAL/ TEST SPLIT ===
#   Test users:   2000 → 1,094,000 rows
#   Train users:  8000 → 4,376,000 rows
#   Val users:    2000   → 1,094,000 rows

# %%
# Check the number of time windows per training user
full_counts = train_df.groupby('User_ID').size()
print(full_counts.describe())
print(f"Unique timestep counts: {full_counts.nunique()}")
# Out:
# count    8000.0
# mean      547.0
# std         0.0
# min       547.0
# 25%       547.0
# 50%       547.0
# 75%       547.0
# max       547.0
# dtype: float64
# Unique timestep counts: 1

# %% [markdown]
# ### 7.1 Train-Only Missing Value Imputation
#
# Missing numeric values are filled using means computed from the training set only. The same training-set fill values are then applied to the validation and test sets.
#
# This avoids data leakage because information from the validation or test set is not used when preparing the training data.

# %%
# Compute fill values from training set ONLY
fill_vals = train_df.mean(numeric_only=True)

train_df.fillna(fill_vals, inplace=True)
val_df.fillna(fill_vals, inplace=True)
test_df.fillna(fill_vals, inplace=True)

# %% [markdown]
# ### 7.2 Active-Throughput Subsets
#
# Because the dataset contains many zero-throughput or idle observations, active-only subsets are created for models or evaluation steps that focus specifically on positive-throughput behavior.
#
# These subsets are useful for the second stage of a two-stage approach: first identifying whether throughput is present, then estimating the throughput value for active samples.

# %%
train_pos = train_df[train_df['Has_Throughput'] == 1].copy()
val_pos = val_df[val_df['Has_Throughput'] == 1].copy()
test_pos  = test_df[test_df['Has_Throughput']  == 1].copy()
print(f"Train active rows: {len(train_pos):,}| Val active rows: {len(val_pos):,} | Test active rows: {len(test_pos):,}")
# Out:
# Train active rows: 1,392,756| Val active rows: 377,766 | Test active rows: 188,845

# %% [markdown]
# ### 7.3 Modeling Configuration and Feature Sets
#
# This cell defines the main modeling configuration used in later experiments. Runtime-safe sample sizes are used because the full aggregated dataset remains large even after 60-second aggregation.
#
# The main clean feature set excludes PRB and `Resource_Efficiency` because these features are closely tied to radio-resource allocation and can behave as shortcut predictors for throughput. A separate leaky upper-bound feature set is optionally defined for comparison, but the main reported models use the cleaner non-leaky feature set.
#
# This setup allows the notebook to compare realistic non-leaky models against an upper-bound configuration while keeping training feasible in Kaggle/Colab.

# %%
# ── Logging config — toggle these freely ──
LOG_CV_VERBOSE    = 3     # 0=silent, 1=time only, 2=score per fold, 3=fold+size
LOG_EPOCH_VERBOSE = True  # DNN epoch-by-epoch loss (final fit only, not during CV)
LOG_RF_TREES      = 1     # RF tree-building progress (0=silent, 1=parallel progress)
RANDOM_STATE = 42
ACTIVE_THRESHOLD = 0.5
SAMPLE_N_S1 = 800_000
SAMPLE_N_S2 = 500_000
N_ESTIMATOR = 100
MAX_DEPTH = 20

# %%
def existing_cols(df, cols):
    return [c for c in cols if c in df.columns]

# %%
leaky_cols     = ['PRB', 'Resource_Efficiency']
state_cols = [c for c in train_df.columns if c.startswith("State_")]
mean_only_cols = ['SINR_UL', 'BLER', 'X_meters', 'Y_meters', 'RU_Current_Load', 'Velocity'] + [crowd_density[1]]
peak_cols      = ['SINR_UL_q90', 'BLER_q10', 'Log_Effective_Signal_Robust']

feature_sets = {
    "D_peak_lagged_non_leaky": existing_cols(train_df, mean_only_cols + peak_cols + state_cols),
}

if any(c in train_df.columns for c in leaky_cols):
    feature_sets["A_leaky_upper_bound"] = existing_cols(
        train_df, mean_only_cols + peak_cols + leaky_cols + state_cols
    )

print("Feature sets:")
for name, feats in feature_sets.items():
    print(f"\n{name}: {len(feats)} features\n{feats}")
# Out:
# Feature sets:
#
# D_peak_lagged_non_leaky: 16 features
# ['SINR_UL', 'BLER', 'X_meters', 'Y_meters', 'RU_Current_Load', 'Velocity', 'Crowd_Density_5m', 'SINR_UL_q90', 'BLER_q10', 'Log_Effective_Signal_Robust', 'State_0', 'State_1', 'State_2', 'State_3', 'State_4', 'State_5']
#
# A_leaky_upper_bound: 18 features
# ['SINR_UL', 'BLER', 'X_meters', 'Y_meters', 'RU_Current_Load', 'Velocity', 'Crowd_Density_5m', 'SINR_UL_q90', 'BLER_q10', 'Log_Effective_Signal_Robust', 'PRB', 'Resource_Efficiency', 'State_0', 'State_1', 'State_2', 'State_3', 'State_4', 'State_5']

# %% [markdown]
# ## 8. Experimental Design
#
# The dataset is split by user ID rather than random rows. This prevents observations from the same user appearing in both training and testing sets, which would make the evaluation overly optimistic.
#
# The test set is kept untouched until the final model comparison.

# %% [markdown]
# ### 8.1 Reproducibility, Evaluation Metrics, and Modeling Utilities
#
# This section defines the shared experimental configuration used across all models. It includes random seeds for reproducibility, model hyperparameters, evaluation metrics, and helper functions for centralized and vertically partitioned learning.
#
# The models are evaluated using both raw-scale and log-scale metrics:
#
# - **MAE** measures the average absolute prediction error in Mbps.
# - **RMSE** penalizes larger prediction errors more strongly.
# - **Raw R²** measures explained variance on the original throughput scale.
# - **Log R²** measures explained variance after reducing the effect of extreme throughput values.
#
# Because the throughput target is highly skewed and zero-heavy, log-scale metrics are especially useful for judging whether the model captures the general throughput pattern.

# %% [markdown]
# ### 8.2 Model Implementation Functions
#
# The following cell defines the reusable model-training and prediction functions used later in the notebook. It does not report final results by itself. Instead, it prepares the components for the later experiments:
#
# 1. **Centralized Random Forest** using a two-stage active/throughput setup.
# 2. **VFL-stacked Random Forest**, where user-side and radio-side models are trained separately and combined by a coordinator.
# 3. **Linear/Ridge coordinator models**, used as the required combined linear baseline for the VFL setup.
# 4. **Centralized Neural Network**, implemented as an LSTM + MLP architecture.
# 5. **VFL Neural Network**, where user-terminal and radio-unit feature groups are processed separately before coordination.
# 6. **Ablation and validation helpers** for checking PRB/resource-efficiency shortcut effects and testing different crowd-density radii.
#
# The actual training and final comparison are performed in later cells.

# %%
# =====================================================================
# 1. CONFIGURATION & DETERMINISM
# =====================================================================
@dataclass
class ExperimentConfig:
    random_state: int = 42
    active_threshold: float = 0.5
    n_estimators: int = 100
    max_depth: int = 20
    use_gpu_rf: bool = False
    rf_n_streams: int = 8
    sample_n_s1: Optional[int] = None
    sample_n_s2: Optional[int] = None

    seq_len: int = 16
    stride: int = 4
    batch_size: int = 256
    lstm_hidden: int = 32
    mlp_hidden: int = 16
    fusion_hidden: int = 32
    num_layers: int = 1
    dropout: float = 0.20
    epochs: int = 20
    patience: int = 4
    lr: float = 1e-3
    weight_decay: float = 1e-5
    meta_frac: float = 0.20

CFG = ExperimentConfig(use_gpu_rf=HAS_CUML)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", DEVICE)
print("cuML RF available:", HAS_CUML)

def seed_everything(seed: int = 42) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    # Force PyTorch Determinism to stop metric drift
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(True, warn_only=True)

seed_everything(CFG.random_state)

def to_numpy_safe(x):
    if cp is not None:
        try:
            if isinstance(x, cp.ndarray):
                return cp.asnumpy(x)
        except Exception:
            pass
    return x.to_numpy() if hasattr(x, "to_numpy") else np.asarray(x)

def sigmoid(x: np.ndarray) -> np.ndarray:
    return 1.0 / (1.0 + np.exp(-x))

# =====================================================================
# 2. METRICS & VISUALIZATION HELPERS
# =====================================================================
def get_metrics(y_true_raw: np.ndarray, y_pred_raw: np.ndarray) -> Dict[str, float]:
    y_true_raw = np.asarray(y_true_raw, dtype=np.float32)
    y_pred_raw = np.clip(np.asarray(y_pred_raw, dtype=np.float32), 0, None)
    y_true_log = np.log1p(y_true_raw)
    y_pred_log = np.log1p(y_pred_raw)
    return {
        "R2_log": r2_score(y_true_log, y_pred_log),
        "RMSE_log": np.sqrt(mean_squared_error(y_true_log, y_pred_log)),
        "MAE_log": mean_absolute_error(y_true_log, y_pred_log),
        "R2_raw": r2_score(y_true_raw, y_pred_raw),
        "RMSE_raw": np.sqrt(mean_squared_error(y_true_raw, y_pred_raw)),
        "MAE_raw": mean_absolute_error(y_true_raw, y_pred_raw),
    }

def print_metric_table(results: Dict[str, Dict[str, float]]) -> pd.DataFrame:
    order = ["R2_log", "RMSE_log", "MAE_log", "R2_raw", "RMSE_raw", "MAE_raw"]
    result_df = pd.DataFrame(results).T[order]
    display(result_df)
    return result_df

def plot_final_comparison(result_df: pd.DataFrame, path: Optional[str] = None) -> None:
    fig, ax = plt.subplots(figsize=(12, 6))
    values = result_df["R2_log"].values
    colors = ['#1f77b4' if 'Central' in idx else '#ff7f0e' if 'VFL' in idx else '#2ca02c' for idx in result_df.index]
    
    bars = ax.bar(result_df.index, values, color=colors, edgecolor='black')
    ax.set_title("Sequence-Aligned Test R² (Log Throughput) - Full Baseline Showdown", fontsize=14, fontweight='bold')
    ax.set_ylabel("R² log Score")
    ax.set_ylim(0, 1.0)
    
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2.0, yval + 0.02, f'{yval:.4f}', ha='center', va='bottom', fontweight='bold')
    
    plt.xticks(rotation=25, ha="right", fontsize=10)
    plt.tight_layout()
    if path:
        plt.savefig(path, dpi=300)
    plt.show()

def sort_for_sequence(df: pd.DataFrame, user_col: str = "User_ID", time_col: str = "Timestamp_Sec") -> pd.DataFrame:
    if time_col in df.columns:
        return df.sort_values([user_col, time_col]).reset_index(drop=True)
    return df.sort_values([user_col]).reset_index(drop=True)

# =====================================================================
# 3. RANDOM FOREST ENGINE
# =====================================================================
# =====================================================================
# 3. RANDOM FOREST ENGINE (WITH WAITABLE PRINTS)
# =====================================================================
def sample_xy(X: np.ndarray, y: np.ndarray, sample_n: Optional[int], seed: int) -> Tuple[np.ndarray, np.ndarray]:
    if sample_n is None or len(X) <= sample_n:
        return X, y
    rng = np.random.default_rng(seed)
    idx = rng.choice(len(X), size=sample_n, replace=False)
    return X[idx], y[idx]

def train_rf_classifier(X: np.ndarray, y: np.ndarray, cfg: ExperimentConfig = CFG):
    X_fit, y_fit = sample_xy(X, y, cfg.sample_n_s1, cfg.random_state)
    mode = "FULL DATASET" if cfg.sample_n_s1 is None else f"SUBSAMPLE ({cfg.sample_n_s1:,})"
    print(f"   [⌛] Fitting Stage 1 Classifier on {mode}: {len(X_fit):,} rows... (Please wait)")
    start_time = time.time()
    
    if cfg.use_gpu_rf and HAS_CUML:
        model = cuRFClassifier(n_estimators=cfg.n_estimators, max_depth=cfg.max_depth, random_state=cfg.random_state, n_streams=cfg.rf_n_streams)
        model.fit(cp.asarray(X_fit.astype(np.float32)), cp.asarray(y_fit.astype(np.int32)))
        backend = "gpu_cuml"
    else:
        model = RandomForestClassifier(n_estimators=cfg.n_estimators, max_depth=cfg.max_depth, n_jobs=-1, random_state=cfg.random_state, class_weight="balanced")
        model.fit(X_fit, y_fit)
        backend = "cpu_sklearn"
        
    print(f"   [✅] Stage 1 Classifier complete in {time.time() - start_time:.1f} seconds.")
    clear_memory()
    return model, backend

def train_rf_regressor(X: np.ndarray, y_log: np.ndarray, cfg: ExperimentConfig = CFG):
    X_fit, y_fit = sample_xy(X, y_log, cfg.sample_n_s2, cfg.random_state)
    mode = "FULL DATASET" if cfg.sample_n_s2 is None else f"SUBSAMPLE ({cfg.sample_n_s2:,})"
    print(f"   [⌛] Fitting Stage 2 Regressor on {mode}: {len(X_fit):,} rows... (Please wait)")
    start_time = time.time()
    
    if cfg.use_gpu_rf and HAS_CUML:
        model = cuRFRegressor(n_estimators=cfg.n_estimators, max_depth=cfg.max_depth, random_state=cfg.random_state, n_streams=cfg.rf_n_streams)
        model.fit(cp.asarray(X_fit.astype(np.float32)), cp.asarray(y_fit.astype(np.float32)))
        backend = "gpu_cuml"
    else:
        model = RandomForestRegressor(n_estimators=cfg.n_estimators, max_depth=cfg.max_depth, n_jobs=-1, random_state=cfg.random_state)
        model.fit(X_fit, y_fit)
        backend = "cpu_sklearn"
        
    print(f"   [✅] Stage 2 Regressor complete in {time.time() - start_time:.1f} seconds.")
    clear_memory()
    return model, backend

def predict_rf(model, backend: str, X: np.ndarray) -> np.ndarray:
    X = X.astype(np.float32)
    if "gpu" in backend.lower() and HAS_CUML:
        X_gpu = cp.asarray(X)
        out = to_numpy_safe(model.predict(X_gpu))
        del X_gpu
        clear_memory()
        return out
    return to_numpy_safe(model.predict(X))

def predict_rf_proba(model, backend: str, X: np.ndarray) -> np.ndarray:
    X = X.astype(np.float32)
    if "gpu" in backend.lower() and HAS_CUML:
        X_gpu = cp.asarray(X)
        out = to_numpy_safe(model.predict_proba(X_gpu))
        del X_gpu
        clear_memory()
        return out[:, 1]
    return to_numpy_safe(model.predict_proba(X))[:, 1]

def train_centralized_rf(train_df: pd.DataFrame, features: Sequence[str], target: str, cfg: ExperimentConfig = CFG) -> Dict:
    train_pos = train_df[train_df["Has_Throughput"] == 1]
    X_s1 = train_df[list(features)].astype(np.float32).values
    y_s1 = train_df["Has_Throughput"].astype(np.int32).values
    X_s2 = train_pos[list(features)].astype(np.float32).values
    y_s2 = np.log1p(train_pos[target].astype(np.float32).values)
    clf, clf_backend = train_rf_classifier(X_s1, y_s1, cfg)
    reg, reg_backend = train_rf_regressor(X_s2, y_s2, cfg)
    return {"clf": clf, "clf_backend": clf_backend, "reg": reg, "reg_backend": reg_backend, "features": list(features)}

def predict_centralized_rf(bundle: Dict, df: pd.DataFrame, cfg: ExperimentConfig = CFG) -> np.ndarray:
    X = df[bundle["features"]].astype(np.float32).values
    active_prob = predict_rf_proba(bundle["clf"], bundle["clf_backend"], X)
    is_active = active_prob >= cfg.active_threshold
    pred_log = predict_rf(bundle["reg"], bundle["reg_backend"], X).ravel()
    return np.clip(np.where(is_active, np.expm1(pred_log), 0.0), 0, None)

def split_base_meta_users(train_df: pd.DataFrame, user_col: str = "User_ID", cfg: ExperimentConfig = CFG) -> Tuple[np.ndarray, np.ndarray]:
    users = train_df[user_col].unique().copy()
    rng = np.random.default_rng(cfg.random_state)
    rng.shuffle(users)
    split_idx = int(len(users) * (1.0 - cfg.meta_frac))
    return users[:split_idx], users[split_idx:]

def predict_single_party_rf(clf, clf_backend, reg, reg_backend, df, features, cfg):
    X = df[list(features)].astype(np.float32).values
    active = predict_rf_proba(clf, clf_backend, X) >= cfg.active_threshold
    pred_log = predict_rf(reg, reg_backend, X).ravel()
    return np.clip(np.where(active, np.expm1(pred_log), 0.0), 0, None)

def train_vfl_stacked_rf(train_df: pd.DataFrame, ue_features: Sequence[str], ru_features: Sequence[str], target: str, user_col: str = "User_ID", cfg: ExperimentConfig = CFG) -> Dict:
    base_users, meta_users = split_base_meta_users(train_df, user_col=user_col, cfg=cfg)
    base_df, meta_df = train_df[train_df[user_col].isin(base_users)].copy(), train_df[train_df[user_col].isin(meta_users)].copy()
    base_pos, meta_pos = base_df[base_df["Has_Throughput"] == 1].copy(), meta_df[meta_df["Has_Throughput"] == 1].copy()

    def prep(df: pd.DataFrame, feats: Sequence[str]) -> np.ndarray: return df[list(feats)].astype(np.float32).values

    ue_clf, ue_clf_backend = train_rf_classifier(prep(base_df, ue_features), base_df["Has_Throughput"].values.astype(np.int32), cfg)
    ru_clf, ru_clf_backend = train_rf_classifier(prep(base_df, ru_features), base_df["Has_Throughput"].values.astype(np.int32), cfg)
    ue_reg, ue_reg_backend = train_rf_regressor(prep(base_pos, ue_features), np.log1p(base_pos[target].values.astype(np.float32)), cfg)
    ru_reg, ru_reg_backend = train_rf_regressor(prep(base_pos, ru_features), np.log1p(base_pos[target].values.astype(np.float32)), cfg)

    meta_s1 = np.column_stack([predict_rf_proba(ue_clf, ue_clf_backend, prep(meta_df, ue_features)), predict_rf_proba(ru_clf, ru_clf_backend, prep(meta_df, ru_features))])
    coord_clf = LogisticRegression(random_state=cfg.random_state, max_iter=1000).fit(meta_s1, meta_df["Has_Throughput"].values.astype(np.int32))

    meta_s2 = np.column_stack([predict_rf(ue_reg, ue_reg_backend, prep(meta_pos, ue_features)).ravel(), predict_rf(ru_reg, ru_reg_backend, prep(meta_pos, ru_features)).ravel()])
    coord_reg = Ridge(alpha=1.0, solver="lsqr", random_state=cfg.random_state).fit(meta_s2, np.log1p(meta_pos[target].values.astype(np.float32)))

    return {"ue_features": list(ue_features), "ru_features": list(ru_features), "base_users": base_users, "meta_users": meta_users,
            "ue_clf": ue_clf, "ue_clf_backend": ue_clf_backend, "ru_clf": ru_clf, "ru_clf_backend": ru_clf_backend,
            "ue_reg": ue_reg, "ue_reg_backend": ue_reg_backend, "ru_reg": ru_reg, "ru_reg_backend": ru_reg_backend,
            "coord_clf": coord_clf, "coord_reg": coord_reg}

def predict_vfl_stacked_rf(bundle: Dict, df: pd.DataFrame) -> np.ndarray:
    X_ue, X_ru = df[bundle["ue_features"]].astype(np.float32).values, df[bundle["ru_features"]].astype(np.float32).values
    meta_s1 = np.column_stack([predict_rf_proba(bundle["ue_clf"], bundle["ue_clf_backend"], X_ue), predict_rf_proba(bundle["ru_clf"], bundle["ru_clf_backend"], X_ru)])
    is_active = bundle["coord_clf"].predict(meta_s1).astype(int) == 1
    meta_s2 = np.column_stack([predict_rf(bundle["ue_reg"], bundle["ue_reg_backend"], X_ue).ravel(), predict_rf(bundle["ru_reg"], bundle["ru_reg_backend"], X_ru).ravel()])
    return np.clip(np.where(is_active, np.expm1(bundle["coord_reg"].predict(meta_s2)), 0.0), 0, None)

def train_linear_vfl_baseline(train_df: pd.DataFrame, features: Sequence[str], target: str, cfg: ExperimentConfig = CFG) -> Dict:
    train_pos = train_df[train_df["Has_Throughput"] == 1].copy()
    clf = make_pipeline(StandardScaler(), LogisticRegression(random_state=cfg.random_state, max_iter=1000)).fit(train_df[list(features)], train_df["Has_Throughput"])
    reg = make_pipeline(StandardScaler(), Ridge(alpha=1.0, solver="lsqr", random_state=cfg.random_state)).fit(train_pos[list(features)], np.log1p(train_pos[target].values.astype(np.float32)))
    return {"clf": clf, "reg": reg, "features": list(features)}

def predict_linear_vfl_baseline(bundle: Dict, df: pd.DataFrame) -> np.ndarray:
    X = df[bundle["features"]].astype(np.float32).values
    return np.clip(np.where(bundle["clf"].predict(X).astype(int) == 1, np.expm1(bundle["reg"].predict(X)), 0.0), 0, None)

# =====================================================================
# 4. DEEP LEARNING ENGINE (LSTM + MLP)
# =====================================================================
class HybridSequenceDataset(Dataset):
    def __init__(self, df: pd.DataFrame, dynamic_cols: Sequence[str], static_cols: Sequence[str], target_col: str, user_col: str, seq_len: int, stride: int, task: str = "classifier", active_only: bool = False, active_col: str = "Has_Throughput"):
        self.df = df.reset_index(drop=True)
        self.dynamic_cols, self.static_cols = list(dynamic_cols), list(static_cols)
        self.task, self.active_only = task, active_only
        self.X_dyn = self.df[self.dynamic_cols].to_numpy(dtype=np.float32)
        self.X_sta = self.df[self.static_cols].to_numpy(dtype=np.float32) if self.static_cols else np.zeros((len(self.df), 0), dtype=np.float32)
        self.y_raw, self.is_active, self.uid = self.df[target_col].to_numpy(dtype=np.float32), self.df[active_col].to_numpy(dtype=np.float32), self.df[user_col].to_numpy()
        
        windows = []
        i, n = 0, len(self.df)
        while i + seq_len <= n:
            start, end = i, i + seq_len - 1
            if np.all(self.uid[start:end + 1] == self.uid[start]):
                if not (self.active_only and self.is_active[end] <= 0):
                    windows.append((start, end))
            i += stride
        self.windows = windows

    def __len__(self) -> int: return len(self.windows)
    def __getitem__(self, idx: int):
        start, end = self.windows[idx]
        y_val = self.is_active[end] if self.task == "classifier" else np.log1p(self.y_raw[end])
        return (torch.from_numpy(self.X_dyn[start:end + 1]), torch.from_numpy(self.X_sta[end]), torch.tensor(y_val, dtype=torch.float32), torch.tensor(self.y_raw[end], dtype=torch.float32), torch.tensor(end, dtype=torch.long))

def make_loader(dataset: Dataset, cfg: ExperimentConfig = CFG, shuffle: bool = False) -> DataLoader:
    return DataLoader(dataset, batch_size=cfg.batch_size, shuffle=shuffle, num_workers=0, pin_memory=(DEVICE.type == "cuda"))

class HybridLSTMMLP(nn.Module):
    def __init__(self, dynamic_dim: int, static_dim: int, lstm_hidden: int = 32, mlp_hidden: int = 16, fusion_hidden: int = 32, num_layers: int = 1, dropout: float = 0.2):
        super().__init__()
        self.static_dim = static_dim
        self.lstm = nn.LSTM(input_size=dynamic_dim, hidden_size=lstm_hidden, num_layers=num_layers, batch_first=True, dropout=dropout if num_layers > 1 else 0.0)
        self.static_mlp = nn.Sequential(nn.Linear(static_dim, mlp_hidden), nn.ReLU(), nn.Dropout(dropout)) if static_dim > 0 else None
        self.head = nn.Sequential(nn.Linear(lstm_hidden + (mlp_hidden if static_dim > 0 else 0), fusion_hidden), nn.ReLU(), nn.Dropout(dropout), nn.Linear(fusion_hidden, 1))

    def forward(self, x_dynamic, x_static):
        lstm_last = self.lstm(x_dynamic)[0][:, -1, :]
        return self.head(torch.cat([lstm_last, self.static_mlp(x_static)], dim=1) if self.static_dim > 0 else lstm_last).squeeze(-1)

def fit_torch_model(model, train_loader, val_loader, criterion, cfg: ExperimentConfig = CFG, run_name="model"):
    optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
    best_val_loss = float("inf")
    best_state = None
    wait = 0
    
    print(f"\n[TRAINING] {run_name}")

    for epoch in range(1, cfg.epochs + 1):
        model.train()
        train_loss_sum = 0.0
        for x_dyn, x_sta, y, _, _ in train_loader:
            optimizer.zero_grad()
            loss = criterion(model(x_dyn.to(DEVICE), x_sta.to(DEVICE)), y.to(DEVICE))
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5.0)
            optimizer.step()
            train_loss_sum += loss.item() * x_dyn.size(0)

        train_loss = train_loss_sum / max(len(train_loader.dataset), 1)

        model.eval()
        val_loss_sum = 0.0
        with torch.no_grad():
            for x_dyn, x_sta, y, _, _ in val_loader:
                val_loss_sum += criterion(model(x_dyn.to(DEVICE), x_sta.to(DEVICE)), y.to(DEVICE)).item() * x_dyn.size(0)
        val_loss = val_loss_sum / max(len(val_loader.dataset), 1)

        # ---------- THIS IS THE ONLY LINE YOU NEED TO ADD ----------
        print(f"Epoch {epoch:02d} | train_loss={train_loss:.5f} | val_loss={val_loss:.5f}")

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            wait = 0
        else:
            wait += 1
            if wait >= cfg.patience:
                print(f"[{run_name}] Early stopping at epoch {epoch}. Best val_loss={best_val_loss:.5f}")
                break

    if best_state is not None:
        model.load_state_dict(best_state)
    return model, None

def predict_torch(model, loader) -> Dict[str, np.ndarray]:
    model.eval()
    preds, ys, y_raws, ends = zip(*[(model(xd.to(DEVICE), xs.to(DEVICE)).detach().cpu().numpy(), y.numpy(), yr.numpy(), e.numpy()) for xd, xs, y, yr, e in loader])
    return {"pred": np.concatenate(preds), "y": np.concatenate(ys), "y_raw": np.concatenate(y_raws), "end_idx": np.concatenate(ends)}

def best_threshold_by_f1(y_true: np.ndarray, prob: np.ndarray) -> Tuple[float, float]:
    thresholds = np.linspace(0.05, 0.95, 19)
    scores = [f1_score(y_true, (prob >= t).astype(int)) for t in thresholds]
    return thresholds[np.argmax(scores)], max(scores)

def make_sequence_loaders(df, dynamic_cols, static_cols, target, user_col, cfg: ExperimentConfig, task="classifier", active_only=False, shuffle=False):
    ds = HybridSequenceDataset(df, dynamic_cols, static_cols, target, user_col, cfg.seq_len, cfg.stride, task, active_only)
    return ds, make_loader(ds, cfg, shuffle)

def predict_single_party_dl(cls_model, reg_model, ann_df, dyn_cols, sta_cols, target, threshold, user_col="User_ID", cfg=None):
    _, cls_loader = make_sequence_loaders(ann_df, dyn_cols, sta_cols, target, user_col, cfg, "classifier", False, False)
    _, reg_loader = make_sequence_loaders(ann_df, dyn_cols, sta_cols, target, user_col, cfg, "regressor", False, False)
    cls_out, reg_out = predict_torch(cls_model, cls_loader), predict_torch(reg_model, reg_loader)
    return np.clip(np.where(sigmoid(cls_out["pred"]) >= threshold, np.clip(np.expm1(reg_out["pred"]), 0, None), 0.0), 0, None), cls_out["y_raw"], cls_out["end_idx"]

def train_centralized_dl(train_ann_df, val_ann_df, dynamic_cols, static_cols, target, user_col="User_ID", cfg: ExperimentConfig = CFG) -> Dict:
    train_cls_ds, train_cls_loader = make_sequence_loaders(train_ann_df, dynamic_cols, static_cols, target, user_col, cfg, "classifier", False, True)
    _, val_cls_loader = make_sequence_loaders(val_ann_df, dynamic_cols, static_cols, target, user_col, cfg, "classifier", False, False)
    _, train_reg_loader = make_sequence_loaders(train_ann_df, dynamic_cols, static_cols, target, user_col, cfg, "regressor", True, True)
    _, val_reg_loader = make_sequence_loaders(val_ann_df, dynamic_cols, static_cols, target, user_col, cfg, "regressor", True, False)

    n_pos = sum(train_cls_ds.is_active[end] > 0 for _, end in train_cls_ds.windows)
    pos_weight = torch.tensor((len(train_cls_ds) - n_pos) / max(n_pos, 1), dtype=torch.float32).to(DEVICE)

    cls_model, _ = fit_torch_model(HybridLSTMMLP(len(dynamic_cols), len(static_cols), **{k: getattr(cfg, k) for k in ['lstm_hidden', 'mlp_hidden', 'fusion_hidden', 'num_layers', 'dropout']}).to(DEVICE), train_cls_loader, val_cls_loader, nn.BCEWithLogitsLoss(pos_weight=pos_weight), cfg)
    best_t, _ = best_threshold_by_f1(predict_torch(cls_model, val_cls_loader)["y"], sigmoid(predict_torch(cls_model, val_cls_loader)["pred"]))
    
    reg_model, _ = fit_torch_model(HybridLSTMMLP(len(dynamic_cols), len(static_cols), **{k: getattr(cfg, k) for k in ['lstm_hidden', 'mlp_hidden', 'fusion_hidden', 'num_layers', 'dropout']}).to(DEVICE), train_reg_loader, val_reg_loader, nn.MSELoss(), cfg)
    return {"cls_model": cls_model, "reg_model": reg_model, "threshold": best_t, "dynamic_cols": list(dynamic_cols), "static_cols": list(static_cols)}

def train_vfl_stacked_dl(train_ann_df, val_ann_df, ue_dyn, ue_sta, ru_dyn, ru_sta, target, base_users, meta_users, user_col="User_ID", cfg: ExperimentConfig = CFG) -> Dict:
    base_df, meta_df = train_ann_df[train_ann_df[user_col].isin(base_users)].copy(), train_ann_df[train_ann_df[user_col].isin(meta_users)].copy()
    
    def party_loaders(df, dyn, sta): return make_sequence_loaders(df, dyn, sta, target, user_col, cfg, "classifier", False, True)[1], make_sequence_loaders(val_ann_df, dyn, sta, target, user_col, cfg, "classifier", False, False)[1], make_sequence_loaders(df, dyn, sta, target, user_col, cfg, "regressor", True, True)[1], make_sequence_loaders(val_ann_df, dyn, sta, target, user_col, cfg, "regressor", True, False)[1]
    
    ue_t_cls, ue_v_cls, ue_t_reg, ue_v_reg = party_loaders(base_df, ue_dyn, ue_sta)
    ru_t_cls, ru_v_cls, ru_t_reg, ru_v_reg = party_loaders(base_df, ru_dyn, ru_sta)
    
    base_cls_ds, _ = make_sequence_loaders(
        base_df, ue_dyn, ue_sta,
        target, user_col, cfg,
        task="classifier",
        active_only=False,
        shuffle=True
    )

    end_indices = np.array([end for _, end in base_cls_ds.windows], dtype=np.int64)
    n_total = len(base_cls_ds)
    n_pos = int((base_cls_ds.is_active[end_indices] > 0).sum()) if n_total > 0 else 0
    n_neg = n_total - n_pos

    print(f"[VFL-DL] Classifier windows: total={n_total:,}, pos={n_pos:,}, neg={n_neg:,}")

    pos_weight = torch.tensor(
        n_neg / max(n_pos, 1),
        dtype=torch.float32
    ).to(DEVICE)
    
    def train_party(tc, vc, tr, vr, dyn, sta, run_name):
        kwargs = {k: getattr(cfg, k) for k in ['lstm_hidden','mlp_hidden','fusion_hidden','num_layers','dropout']}
        cls_model, _ = fit_torch_model(HybridLSTMMLP(len(dyn), len(sta), **kwargs).to(DEVICE),tc, vc, nn.BCEWithLogitsLoss(pos_weight=pos_weight), cfg, run_name=run_name+"_CLS")
        val_cls = predict_torch(cls_model, vc)
        party_threshold, _ = best_threshold_by_f1(val_cls["y"], sigmoid(val_cls["pred"]))
        reg_model, _ = fit_torch_model(HybridLSTMMLP(len(dyn), len(sta), **kwargs).to(DEVICE),tr, vr, nn.MSELoss(), cfg, run_name=run_name+"_REG")
        return cls_model, reg_model, party_threshold
    
    ue_cls, ue_reg, ue_threshold = train_party(ue_t_cls, ue_v_cls, ue_t_reg, ue_v_reg, ue_dyn, ue_sta, run_name="UE")
    ru_cls, ru_reg, ru_threshold = train_party(ru_t_cls, ru_v_cls, ru_t_reg, ru_v_reg, ru_dyn, ru_sta, run_name="RU")

    ue_mc, ru_mc = predict_torch(ue_cls, make_sequence_loaders(meta_df, ue_dyn, ue_sta, target, user_col, cfg, "classifier", False, False)[1]), predict_torch(ru_cls, make_sequence_loaders(meta_df, ru_dyn, ru_sta, target, user_col, cfg, "classifier", False, False)[1])
    meta_s1 = np.column_stack([sigmoid(ue_mc["pred"]), sigmoid(ru_mc["pred"])])
    coord_clf = LogisticRegression(random_state=cfg.random_state, max_iter=1000).fit(np.column_stack([sigmoid(ue_mc["pred"]), sigmoid(ru_mc["pred"])]), ue_mc["y"])
    coord_prob = coord_clf.predict_proba(meta_s1)[:, 1]
    coord_threshold, _ = best_threshold_by_f1(ue_mc["y"], coord_prob)
    
    ue_mr, ru_mr = predict_torch(ue_reg, make_sequence_loaders(meta_df, ue_dyn, ue_sta, target, user_col, cfg, "regressor", True, False)[1]), predict_torch(ru_reg, make_sequence_loaders(meta_df, ru_dyn, ru_sta, target, user_col, cfg, "regressor", True, False)[1])
    coord_reg = make_pipeline(StandardScaler(),Ridge(alpha=1.0, solver="lsqr", random_state=cfg.random_state)).fit(np.column_stack([ue_mr["pred"], ru_mr["pred"]]),ue_mr["y"])
    return {"ue_cls": ue_cls,"ru_cls": ru_cls,"ue_reg": ue_reg,"ru_reg": ru_reg,"coord_clf": coord_clf,"coord_reg": coord_reg,"coord_threshold": coord_threshold,"ue_threshold": ue_threshold,"ru_threshold": ru_threshold,"ue_dyn": list(ue_dyn), "ue_sta": list(ue_sta),"ru_dyn": list(ru_dyn),"ru_sta": list(ru_sta),}

def predict_centralized_dl(bundle, ann_df, target, user_col="User_ID", cfg: ExperimentConfig = CFG):
    cls_out = predict_torch(bundle["cls_model"], make_sequence_loaders(ann_df, bundle["dynamic_cols"], bundle["static_cols"], target, user_col, cfg, "classifier", False, False)[1])
    reg_out = predict_torch(bundle["reg_model"], make_sequence_loaders(ann_df, bundle["dynamic_cols"], bundle["static_cols"], target, user_col, cfg, "regressor", False, False)[1])
    return np.clip(np.where(sigmoid(cls_out["pred"]) >= bundle["threshold"], np.clip(np.expm1(reg_out["pred"]), 0, None), 0.0), 0, None), cls_out["y_raw"], cls_out["end_idx"]

def predict_vfl_stacked_dl(
    bundle,
    ann_df,
    target,
    expected_end_idx,
    threshold,
    user_col="User_ID",
    cfg=CFG,
    return_debug=False,
):
    # Safely cast indices to integer
    expected_end_idx = np.asarray(expected_end_idx).astype(int)

    # Local Sigmoid helper
    def sigmoid(x):
        return 1.0 / (1.0 + np.exp(-x))

    # 1. Get raw outputs from each party using predict_torch (returns dictionaries)
    ue_c = predict_torch(bundle["ue_cls"],make_sequence_loaders(ann_df, bundle["ue_dyn"], bundle["ue_sta"],target, user_col, cfg, "classifier", False, False)[1])
    ru_c = predict_torch(
        bundle["ru_cls"],
        make_sequence_loaders(
            ann_df, bundle["ru_dyn"], bundle["ru_sta"],
            target, user_col, cfg, "classifier", False, False
        )[1]
    )
    ue_r = predict_torch(
        bundle["ue_reg"],
        make_sequence_loaders(
            ann_df, bundle["ue_dyn"], bundle["ue_sta"],
            target, user_col, cfg, "regressor", False, False
        )[1]
    )
    ru_r = predict_torch(
        bundle["ru_reg"],
        make_sequence_loaders(
            ann_df, bundle["ru_dyn"], bundle["ru_sta"],   # ← fixed: now uses RU columns
            target, user_col, cfg, "regressor", False, False
        )[1]
    )

    # 2. Hard alignment checks
    assert np.array_equal(ue_c["end_idx"].astype(int), expected_end_idx), "UE classifier end_idx mismatch"
    assert np.array_equal(ru_c["end_idx"].astype(int), expected_end_idx), "RU classifier end_idx mismatch"
    assert np.array_equal(ue_r["end_idx"].astype(int), expected_end_idx), "UE regressor end_idx mismatch"
    assert np.array_equal(ru_r["end_idx"].astype(int), expected_end_idx), "RU regressor end_idx mismatch"

    y_expected = ann_df.iloc[expected_end_idx][target].values.astype(np.float32)
    assert np.allclose(ue_c["y_raw"], y_expected), "VFL y_raw mismatch vs expected rows"

    # 3. Stack classifier predictions and apply coordinator
    meta_s1 = np.column_stack([sigmoid(ue_c["pred"]), sigmoid(ru_c["pred"])])
    if hasattr(bundle["coord_clf"], "predict_proba"):
        active_prob = bundle["coord_clf"].predict_proba(meta_s1)[:, 1]
        coord_threshold = bundle.get("coord_threshold", threshold)
        is_active = active_prob >= coord_threshold
    else:
        active_prob = None
        is_active = bundle["coord_clf"].predict(meta_s1).astype(int) == 1

    # 4. Stack regressor predictions and apply coordinator
    meta_s2 = np.column_stack([ue_r["pred"], ru_r["pred"]])
    pred_log = bundle["coord_reg"].predict(meta_s2)
    pred_raw = np.clip(np.expm1(pred_log), 0, None)
    
    # 5. Mask with activity classification
    final_pred = np.where(is_active, pred_raw, 0.0)
    final_pred = np.clip(final_pred, 0, None)

    if return_debug:
        return final_pred, {
            "y_raw": ue_c["y_raw"],
            "end_idx": ue_c["end_idx"],
            "is_active": is_active,
        }

    return final_pred
# def predict_vfl_stacked_dl(bundle, ann_df, target, expected_end_idx, threshold, user_col="User_ID", cfg: ExperimentConfig = CFG):
#     ue_c, ru_c = predict_torch(bundle["ue_cls"], make_sequence_loaders(ann_df, bundle["ue_dyn"], bundle["ue_sta"], target, user_col, cfg, "classifier", False, False)[1]), predict_torch(bundle["ru_cls"], make_sequence_loaders(ann_df, bundle["ru_dyn"], bundle["ru_sta"], target, user_col, cfg, "classifier", False, False)[1])
#     ue_r, ru_r = predict_torch(bundle["ue_reg"], make_sequence_loaders(ann_df, bundle["ue_dyn"], bundle["ue_sta"], target, user_col, cfg, "regressor", False, False)[1]), predict_torch(bundle["ru_reg"], make_sequence_loaders(ann_df, bundle["ru_dyn"], bundle["ru_sta"], target, user_col, cfg, "regressor", False, False)[1])
#     return np.clip(np.where(bundle["coord_clf"].predict(np.column_stack([sigmoid(ue_c["pred"]), sigmoid(ru_c["pred"])])) == 1, np.expm1(bundle["coord_reg"].predict(np.column_stack([ue_r["pred"], ru_r["pred"]]))), 0.0), 0, None)

# =====================================================================
# 5. ABLATION & VALIDATION REPORTING EXPERIMENTS
# =====================================================================
def prove_prb_leakage(train_df, val_df, non_leaky_feats, leaky_feats, target, cfg):
    """Prove leakage by comparing A (leaky) vs D (non-leaky) on validation."""
    print("\n" + "⚠️" * 35)
    print("  ⚠️ SCIENTIFIC JUSTIFICATION: PRB & RESOURCE EFFICIENCY LEAKAGE ABLATION")
    print("⚠️" * 35)

    # Leaky set A
    bundle_leaky = train_centralized_rf(train_df, leaky_feats, target, cfg)
    pred_leaky = predict_centralized_rf(bundle_leaky, val_df, cfg)
    met_leaky = get_metrics(val_df[target].values.astype(np.float32), pred_leaky)

    # Non-leaky set D
    bundle_clean = train_centralized_rf(train_df, non_leaky_feats, target, cfg)
    pred_clean = predict_centralized_rf(bundle_clean, val_df, cfg)
    met_clean = get_metrics(val_df[target].values.astype(np.float32), pred_clean)

    print("\nValidation R²_log comparison:")
    print(f"  Leaky (PRB+Resource_Efficiency): {met_leaky['R2_log']:.4f}")
    print(f"  Clean (non-leaky)              : {met_clean['R2_log']:.4f}")
    print(f"  R² inflation = {met_leaky['R2_log'] - met_clean['R2_log']:.4f}")

    # Feature importances for the leaky model (both stages)
    def show_imps(bundle, title):
        for stage, key in [("Stage 1 Classifier", "clf"), ("Stage 2 Regressor", "reg")]:
            model = bundle[key]
            feats = bundle["features"]
            if key == "clf" and "gpu" in bundle.get("clf_backend", ""):
                imps = cp.asnumpy(model.feature_importances_)
            else:
                imps = model.feature_importances_
            imp_df = pd.DataFrame({"Feature": feats, "Importance": imps}).sort_values("Importance", ascending=False)
            print(f"\n{title} – {stage} feature importances:")
            print(imp_df.head(5).to_string(index=False))

    show_imps(bundle_leaky, "Leaky set")
    show_imps(bundle_clean, "Clean set")

    print("\nCONCLUSION: PRB and Resource_Efficiency dominate the leaky model, inflating R²_log by up to {:.4f}. They are excluded from all further experiments.".format(met_leaky['R2_log'] - met_clean['R2_log']))

def ablate_crowd_density_radius(train_df, val_df, base_feats_no_density, crowd_density_cols, target, cfg):
    """Satisfies the rubric requirement: 'experiment different values of X'"""
    print("\n" + "=" * 65)
    print("   ABLATION -- Crowd Density Radius X (Validation Set)")
    print("=" * 65)
    results = {}
    for col in crowd_density_cols:
        feats = base_feats_no_density + [col]
        bundle = train_centralized_rf(train_df, feats, target, cfg)
        pred = predict_centralized_rf(bundle, val_df, cfg)
        results[f"Radius: {col.split('_')[-1]}"] = get_metrics(val_df[target].values.astype(np.float32), pred)
    print_metric_table(results)

def report_rf_validation(central_rf, vfl_rf, linear_vfl, val_df, target, cfg):
    print("\n" + "=" * 65)
    print("   VALIDATION COMPARISON -- RF-BASED MODELS (val set)")
    print("=" * 65)
    y_val = val_df[target].values.astype(np.float32)
    results = {}

    pred = predict_centralized_rf(central_rf, val_df, cfg)
    results["Central RF"] = get_metrics(y_val, pred)
    del pred, central_rf; clear_memory()

    pred = predict_vfl_stacked_rf(vfl_rf, val_df)
    results["VFL-Stacked RF"] = get_metrics(y_val, pred)
    del pred; clear_memory()

    pred = predict_single_party_rf(vfl_rf["ue_clf"], vfl_rf["ue_clf_backend"], vfl_rf["ue_reg"], vfl_rf["ue_reg_backend"], val_df, vfl_rf["ue_features"], cfg)
    results["UE-Only RF (Baseline)"] = get_metrics(y_val, pred)
    del pred; clear_memory()

    pred = predict_single_party_rf(vfl_rf["ru_clf"], vfl_rf["ru_clf_backend"], vfl_rf["ru_reg"], vfl_rf["ru_reg_backend"], val_df, vfl_rf["ru_features"], cfg)
    results["RU-Only RF (Baseline)"] = get_metrics(y_val, pred)
    del vfl_rf, pred; clear_memory()

    pred = predict_linear_vfl_baseline(linear_vfl, val_df)
    results["Linear VFL"] = get_metrics(y_val, pred)
    del linear_vfl, pred; clear_memory()

    print_metric_table(results)
    return results

def report_dl_validation(central_dl, vfl_dl, val_ann, target, cfg, user_col="User_ID"):
    print("\n" + "=" * 65)
    print("   VALIDATION COMPARISON -- DL-BASED MODELS (val set)")
    print("=" * 65)
    results = {}

    cent_pred, y_val, val_end_idx = predict_centralized_dl(central_dl, val_ann, target, user_col, cfg)
    results["Central LSTM+MLP"] = get_metrics(y_val, cent_pred)
    del cent_pred; clear_memory()

    pred = predict_vfl_stacked_dl(vfl_dl, val_ann, target, val_end_idx,vfl_dl.get("coord_threshold", central_dl["threshold"]),user_col, cfg)
    results["VFL-Stacked LSTM+MLP"] = get_metrics(y_val, pred)
    del pred; clear_memory()

    pred, _, _ = predict_single_party_dl(vfl_dl["ue_cls"], vfl_dl["ue_reg"], val_ann, vfl_dl["ue_dyn"], vfl_dl["ue_sta"], target,vfl_dl.get("ue_threshold", central_dl["threshold"]),user_col, cfg)
    results["UE-Only LSTM+MLP (Baseline)"] = get_metrics(y_val, pred)
    del pred; clear_memory()

    pred, _, _ = predict_single_party_dl(vfl_dl["ru_cls"], vfl_dl["ru_reg"], val_ann,vfl_dl["ru_dyn"], vfl_dl["ru_sta"], target,vfl_dl.get("ru_threshold", central_dl["threshold"]),user_col, cfg)
    results["RU-Only LSTM+MLP (Baseline)"] = get_metrics(y_val, pred)
    del pred; clear_memory()

    print_metric_table(results)
    return results
    
user_col="User_ID"
time_col="Timestamp_Sec"
best_feats = feature_sets["D_peak_lagged_non_leaky"]
crowd_density = ["Crowd_Density_2m", "Crowd_Density_5m", "Crowd_Density_10m"]
ue_features = ["X_meters", "Y_meters", "Velocity"] + state_cols
ru_features = ["SINR_UL", "BLER", "RU_Current_Load", "Log_Effective_Signal_Robust", "SINR_UL_q90", "BLER_q10"] + [crowd_density[1]]
# Out:
# Device: cuda
# cuML RF available: True

# %% [markdown]
# ## 9. Ablation Studies
#
# Before training the final centralized and VFL models, two validation-set ablations are performed. The first ablation selects the most suitable crowd-density radius for the Team 9 X-meter feature. The second ablation checks whether PRB and `Resource_Efficiency` act as shortcut/leakage-risk features.
#
# Both ablations are run on the validation set using runtime-safe sample sizes to keep the experiment feasible in Kaggle/Colab.

# %% [markdown]
# ### 9.1 Ablation 1: Crowd-Density Radius Selection
#
# Project 9 requires Team 9 to use the number of users within X meters of the target device. To test this requirement, crowd-density features are computed for multiple radius values: 2m, 5m, and 10m.
#
# These features measure the same local-crowding effect at different spatial scales, so they are expected to be correlated. The ablation compares the model performance obtained with each radius and checks whether one radius provides a better tradeoff between local detail and stability.
#
# The final feature set keeps the 5m crowd-density feature because it provides a balanced spatial scale: 2m can be too local and sparse, while 10m can be more general and redundant with broader crowd behavior.

# %% [markdown]
# ### 9.2 Ablation 2: PRB and Resource-Efficiency Leakage-Risk Check
#
# This ablation compares a centralized Random Forest trained with the clean non-leaky feature set against the same model trained with `PRB` and `Resource_Efficiency` added.
#
# These two features are treated carefully because PRB represents scheduler resource allocation, which is directly related to throughput. As a result, PRB-based features can behave like shortcut predictors: they may improve validation performance, but they may also make the prediction task less realistic if the goal is to estimate throughput before knowing final resource allocation.
#
# The purpose of this ablation is to quantify how much performance changes when these leakage-risk features are included. For the main reported experiments, the clean feature set is used to avoid relying on scheduler-allocation shortcuts.

# %% [markdown]
# ### 9.3 Leakage-Risk and Crowd-Density Ablation Setup
#
# This cell runs two validation-set ablations.
#
# First, the clean non-leaky feature set is compared with an extended feature set that adds `PRB` and `Resource_Efficiency`. These features are examined because PRB is closely tied to scheduler resource allocation and may act as a shortcut predictor for throughput.
#
# Second, the three Team 9 crowd-density radii, 2m, 5m, and 10m, are compared. This checks whether the final model should use one radius or keep multiple highly related density features.

# %%
# 1. Configuration Setup for Fast Prototyping
fast_cfg = copy.deepcopy(CFG)
fast_cfg.sample_n_s1 = 800_000
fast_cfg.sample_n_s2 = 500_000

# 2. Execute PRB Leakage Proof
leaky_feats = best_feats + ['PRB', 'Resource_Efficiency']
print("[⌛] Running PRB Leakage Ablation Analysis...")
prove_prb_leakage(train_df, val_df, best_feats, leaky_feats, target, fast_cfg)

# 3. Crowd Density Correlation Audit & Radius Selection
print("\n" + "=" * 65)
print("   CROWD DENSITY CORRELATION AUDIT")
print("=" * 65)
display(train_df[crowd_density].corr())

print("\n[⌛] Running Crowd Density Radius Ablation Analysis...")
base_feats_no_density = [f for f in best_feats if f not in crowd_density]
ablate_crowd_density_radius(train_df, val_df, base_feats_no_density, crowd_density, target, fast_cfg)

clear_memory()
# Out:
# [⌛] Running PRB Leakage Ablation Analysis...
#
# ⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️
#   ⚠️ SCIENTIFIC JUSTIFICATION: PRB & RESOURCE EFFICIENCY LEAKAGE ABLATION
# ⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️
#    [⌛] Fitting Stage 1 Classifier on SUBSAMPLE (800,000): 800,000 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 4.2 seconds.
#    [⌛] Fitting Stage 2 Regressor on SUBSAMPLE (500,000): 500,000 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 16.9 seconds.
#    [⌛] Fitting Stage 1 Classifier on SUBSAMPLE (800,000): 800,000 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 2.1 seconds.
#    [⌛] Fitting Stage 2 Regressor on SUBSAMPLE (500,000): 500,000 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 15.9 seconds.
#
# Validation R²_log comparison:
#   Leaky (PRB+Resource_Efficiency): 0.8175
#   Clean (non-leaky)              : 0.7967
#   R² inflation = 0.0208
#
# Leaky set – Stage 1 Classifier feature importances:
#             Feature  Importance
# Resource_Efficiency    0.275593
#                BLER    0.231101
#                 PRB    0.208353
#             State_1    0.119469
#            BLER_q10    0.110740
#
# Leaky set – Stage 2 Regressor feature importances:
#                     Feature  Importance
#         Resource_Efficiency    0.444709
#                        BLER    0.193623
# Log_Effective_Signal_Robust    0.069909
#                     SINR_UL    0.063889
#             RU_Current_Load    0.059608
#
# Clean set – Stage 1 Classifier feature importances:
#  Feature  Importance
#     BLER    0.361932
# BLER_q10    0.341149
#  State_1    0.218493
#  State_2    0.036223
#  State_5    0.024959
#
# Clean set – Stage 2 Regressor feature importances:
#                     Feature  Importance
#             RU_Current_Load    0.300158
#                        BLER    0.265966
# Log_Effective_Signal_Robust    0.101802
#                     SINR_UL    0.092409
#                    X_meters    0.047964
#
# CONCLUSION: PRB and Resource_Efficiency dominate the leaky model, inflating R²_log by up to 0.0208. They are excluded from all further experiments.
#
# =================================================================
#    CROWD DENSITY CORRELATION AUDIT
# =================================================================
#                    Crowd_Density_2m  Crowd_Density_5m  Crowd_Density_10m
# Crowd_Density_2m           1.000000          0.970948           0.850089
# Crowd_Density_5m           0.970948          1.000000           0.882925
# Crowd_Density_10m          0.850089          0.882925           1.000000
# [⌛] Running Crowd Density Radius Ablation Analysis...
#
# =================================================================
#    ABLATION -- Crowd Density Radius X (Validation Set)
# =================================================================
#    [⌛] Fitting Stage 1 Classifier on SUBSAMPLE (800,000): 800,000 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 2.1 seconds.
#    [⌛] Fitting Stage 2 Regressor on SUBSAMPLE (500,000): 500,000 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 15.8 seconds.
#    [⌛] Fitting Stage 1 Classifier on SUBSAMPLE (800,000): 800,000 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 2.0 seconds.
#    [⌛] Fitting Stage 2 Regressor on SUBSAMPLE (500,000): 500,000 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 15.9 seconds.
#    [⌛] Fitting Stage 1 Classifier on SUBSAMPLE (800,000): 800,000 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 2.0 seconds.
#    [⌛] Fitting Stage 2 Regressor on SUBSAMPLE (500,000): 500,000 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 16.2 seconds.
#                R2_log  RMSE_log   MAE_log    R2_raw  RMSE_raw   MAE_raw
# Radius: 2m   0.795932  0.368122  0.164772  0.228430  6.521883  1.219084
# Radius: 5m   0.796544  0.367570  0.164517  0.230952  6.511214  1.217791
# Radius: 10m  0.795708  0.368324  0.164932  0.223306  6.543504  1.222733

# %% [markdown]
# The PRB/resource-efficiency ablation shows that adding these features improves validation log R² from 0.7967 to 0.8175, an increase of 0.0208. This confirms that the PRB-related features contain useful predictive information.
#
# However, the feature-importance results show that `Resource_Efficiency` and `PRB` dominate the leaky model, especially in the Stage 2 regressor where `Resource_Efficiency` receives the highest importance. Since PRB is directly related to scheduler resource allocation, relying on it can make the model less realistic for a pre-allocation throughput prediction scenario.
#
# For this reason, the main reported models use the clean non-leaky feature set, while the PRB-included result is treated as an upper-bound or leakage-risk comparison.
#
#
# The crowd-density ablation shows that the 2m, 5m, and 10m radii produce very similar validation performance, which is expected because the density features are strongly correlated. The 5m radius gives the best validation log R² among the tested radii and is therefore kept as the final Team 9 X-meter feature.
#
# This satisfies the Team 9 requirement to experiment with different values of X while avoiding redundant density features in the final clean model.

# %% [markdown]
# ## 10. Runtime-Aware Hyperparameter Tuning
#
# Because the full aggregated dataset remains large even after 60-second preprocessing, hyperparameter tuning is performed on a representative subset of training users rather than on the full dataset. This keeps the experiment feasible in Kaggle/Colab while still preserving the natural idle/active class distribution.
#
# For Random Forest, 1,000 users are sampled from the training set and evaluated using **GroupKFold cross-validation**, where folds are split by `User_ID`. This prevents the same user's time-series samples from appearing in both training and validation folds during tuning.
#
# The tuning compares a small grid of tree counts and maximum depths. The best configuration is then used for the final Random Forest training and evaluation.

# %%
# ═══════════════════════════════════════════════════════════════
# HYPERPARAMETER TUNING ON TRAIN SET ONLY (RF )
# – uses 1,000 random users, preserves natural class distribution
# – GroupKFold (3 folds) for both models
# ═══════════════════════════════════════════════════════════════
# 1. Sample 1,000 users from train_df (keeps ~70% idle rows)
np.random.seed(CFG.random_state)
all_train_users = train_df['User_ID'].unique()
subset_cv_users = np.random.choice(all_train_users, size=1000, replace=False)
tune_train_df = train_df[train_df['User_ID'].isin(subset_cv_users)].copy()

print(f"Tuning subset: {len(subset_cv_users)} users, {len(tune_train_df)} rows "
      f"({tune_train_df['Has_Throughput'].mean()*100:.1f}% active)")

# 2. RF tuning config (subsampled rows for speed, no class balancing here)
rf_tune_cfg = copy.deepcopy(CFG)

rf_param_grid = [
    {'n_estimators': 100, 'max_depth': 20},
    {'n_estimators': 200, 'max_depth': 20},
    {'n_estimators': 100, 'max_depth': 30},
]

kf = GroupKFold(n_splits=3)
rf_best_score = -np.inf
rf_best_params = None

print("\n--- RF Hyperparameter Tuning (GroupKFold, train only) ---")
for params in rf_param_grid:
    fold_scores = []
    for fold, (train_idx, val_idx) in enumerate(kf.split(tune_train_df, groups=tune_train_df['User_ID'])):
        tr = tune_train_df.iloc[train_idx].copy() 
        vl = tune_train_df.iloc[val_idx].copy()
        # Sub-sample rows if you want extra speed (preserves class ratio)
        # Here we simply use all rows of these users; that's ~350k train, 175k val per fold
        cfg_tmp = copy.deepcopy(rf_tune_cfg)
        cfg_tmp.n_estimators = params['n_estimators']
        cfg_tmp.max_depth = params['max_depth']
        
        bundle = train_centralized_rf(tr, best_feats, target, cfg_tmp)
        pred = predict_centralized_rf(bundle, vl, cfg_tmp)
        y_val = vl[target].values.astype(np.float32)
        r2 = get_metrics(y_val, pred)['R2_log']
        fold_scores.append(r2)
        
        # AGGRESSIVE MEMORY CLEANUP
        del tr, vl, bundle, pred, y_val, cfg_tmp
        clear_memory()
    avg, std = np.mean(fold_scores), np.std(fold_scores)
    print(f"n_est={params['n_estimators']}, depth={params['max_depth']} → R²_log = {avg:.4f} ± {std:.4f}")
    if avg > rf_best_score:
        rf_best_score = avg
        rf_best_params = params

print(f"Best RF params: {rf_best_params}, CV R²_log = {rf_best_score:.4f}")
# Override final CFG with best RF parameters
CFG.n_estimators = rf_best_params['n_estimators']
CFG.max_depth = rf_best_params['max_depth']
# Out:
# Tuning subset: 1000 users, 547000 rows (30.8% active)
#
# --- RF Hyperparameter Tuning (GroupKFold, train only) ---
#    [⌛] Fitting Stage 1 Classifier on FULL DATASET: 364,302 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 0.9 seconds.
#    [⌛] Fitting Stage 2 Regressor on FULL DATASET: 110,454 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 3.7 seconds.
#    [⌛] Fitting Stage 1 Classifier on FULL DATASET: 364,849 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 0.9 seconds.
#    [⌛] Fitting Stage 2 Regressor on FULL DATASET: 115,891 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 3.8 seconds.
#    [⌛] Fitting Stage 1 Classifier on FULL DATASET: 364,849 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 0.9 seconds.
#    [⌛] Fitting Stage 2 Regressor on FULL DATASET: 110,429 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 3.7 seconds.
# n_est=100, depth=20 → R²_log = 0.7844 ± 0.0057
#    [⌛] Fitting Stage 1 Classifier on FULL DATASET: 364,302 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 1.6 seconds.
#    [⌛] Fitting Stage 2 Regressor on FULL DATASET: 110,454 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 8.3 seconds.
#    [⌛] Fitting Stage 1 Classifier on FULL DATASET: 364,849 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 1.7 seconds.
#    [⌛] Fitting Stage 2 Regressor on FULL DATASET: 115,891 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 8.7 seconds.
#    [⌛] Fitting Stage 1 Classifier on FULL DATASET: 364,849 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 1.7 seconds.
#    [⌛] Fitting Stage 2 Regressor on FULL DATASET: 110,429 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 8.3 seconds.
# n_est=200, depth=20 → R²_log = 0.7856 ± 0.0056
#    [⌛] Fitting Stage 1 Classifier on FULL DATASET: 364,302 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 0.9 seconds.
#    [⌛] Fitting Stage 2 Regressor on FULL DATASET: 110,454 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 7.4 seconds.
#    [⌛] Fitting Stage 1 Classifier on FULL DATASET: 364,849 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 0.9 seconds.
#    [⌛] Fitting Stage 2 Regressor on FULL DATASET: 115,891 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 8.2 seconds.
#    [⌛] Fitting Stage 1 Classifier on FULL DATASET: 364,849 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 0.9 seconds.
#    [⌛] Fitting Stage 2 Regressor on FULL DATASET: 110,429 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 7.4 seconds.
# n_est=100, depth=30 → R²_log = 0.7801 ± 0.0057
# Best RF params: {'n_estimators': 200, 'max_depth': 20}, CV R²_log = 0.7856

# %% [markdown]
# The Random Forest tuning results show that `n_estimators=200` and `max_depth=20` achieved the highest average validation log-scale R². The improvement over `n_estimators=100, max_depth=20` is small, but the 200-tree model gives the best cross-validation score while remaining computationally feasible.
#
# The deeper `max_depth=30` configuration did not improve performance, suggesting that additional tree depth may overfit or add complexity without better generalization. Therefore, the final Random Forest configuration uses 200 trees with maximum depth 20.

# %% [markdown]
# ### 10.1 Sequence Alignment for Neural-Network Models
#
# Before training the LSTM + MLP models, the train, validation, and test sets are sorted by `User_ID` and timestamp. This ensures that sequence windows are built in the correct temporal order for each user.
#
# Separate copies are also kept for the classical Random Forest models, which do not require sequence windows but use the same underlying train/validation/test split for fair comparison.

# %%
# Synchronize user timeline sequences across datasets
user_col, time_col = "User_ID", "Timestamp_Sec"
train_df = sort_for_sequence(train_df, user_col, time_col)
val_df   = sort_for_sequence(val_df, user_col, time_col)
test_df  = sort_for_sequence(test_df, user_col, time_col)

# Create standalone copies for classical models
rf_train_raw = train_df.copy()
rf_val_raw   = val_df.copy()
rf_test_raw  = test_df.copy()

print(f"[✅] Sequential data sorted. Base records: {len(rf_train_raw):,}")
# Out:
# [✅] Sequential data sorted. Base records: 4,376,000

# %% [markdown]
# ## 11. Centralized Random Forest Two-Stage Model
#
# Random Forest is used as the classical machine-learning baseline required by the assignment. The model is trained in a centralized setting, meaning it has access to the full selected clean feature set.
#
# Because the throughput target is zero-heavy, the Random Forest is implemented as a two-stage model:
#
# 1. **Stage 1 — Active/Idle classifier:** predicts whether a user has positive throughput in the current 60-second window.
# 2. **Stage 2 — Log-throughput regressor:** trains only on active-throughput samples and predicts `log(1 + Throughput)`.
#
# This design directly addresses the idle-dominant nature of the dataset. The first stage handles the active/idle decision, while the second stage estimates the throughput magnitude only when the user is predicted to be active. Both stages use Random Forest models to capture nonlinear relationships among radio-quality, spatial, mobility, traffic-state, and crowd-density features.

# %%
print("➡ [⌛] Training Centralized Random Forest on 100% Data...")
central_rf = train_centralized_rf(rf_train_raw, best_feats, target, CFG)

# Persist to disk and release memory footprint
working_dir = working
joblib.dump(central_rf, os.path.join(working_dir, "central_rf.joblib"))

del central_rf
clear_memory()
# Out:
# ➡ [⌛] Training Centralized Random Forest on 100% Data...
#    [⌛] Fitting Stage 1 Classifier on FULL DATASET: 4,376,000 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 25.8 seconds.
#    [⌛] Fitting Stage 2 Regressor on FULL DATASET: 1,392,756 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 83.4 seconds.

# %% [markdown]
# The centralized Random Forest was trained on the full training split. Stage 1 used all training rows to learn the active/idle classification task, while Stage 2 used only active-throughput rows for log-throughput regression.
#
# The difference in row counts confirms the zero-heavy nature of the dataset: only a subset of the training windows contain positive throughput. This supports the two-stage design, since treating all rows as a single regression problem would force the model to handle idle and active behavior simultaneously.

# %% [markdown]
# ## 12. VFL-Stacked Random Forest
#
# The VFL-stacked Random Forest simulates a vertical federated learning setup where different feature groups are owned by different parties. Instead of training one centralized model on all features, the feature set is split into two views:
#
# - **User Equipment (UE) features:** user position, movement, and traffic-state/context features.
# - **Radio Unit (RU) features:** SINR, BLER, radio-unit load, effective signal quality, and the selected 5m crowd-density feature.
#
# The training protocol uses a base/meta split within the training users:
#
# 1. Training users are split into a **base group** and a **meta group**.
# 2. Separate two-stage Random Forest models are trained for the UE and RU feature groups using only the base group.
# 3. Each local model generates predictions on the meta group.
# 4. A lightweight coordinator combines the local outputs using Logistic Regression for the active/idle stage and Ridge Regression for the log-throughput stage.
#
# The coordinator only receives the outputs of the local UE and RU models, not the raw feature columns. This simulates the vertical FL idea required by the project while keeping the implementation practical for the notebook.
#
# In this partition, `Crowd_Density_5m` is treated as RU-side/network-side context because it represents local multi-user congestion around the target user.

# %%
print("➡ [⌛] Training VFL-Stacked Random Forest...")
vfl_rf = train_vfl_stacked_rf(rf_train_raw, ue_features, ru_features, target, user_col="User_ID", cfg=CFG)

# Cache both the model ensemble and the user partition splits
joblib.dump(vfl_rf, os.path.join(working_dir, "vfl_rf.joblib"))
np.save(os.path.join(working_dir, "vfl_base_users.npy"), vfl_rf["base_users"])
np.save(os.path.join(working_dir, "vfl_meta_users.npy"), vfl_rf["meta_users"])

del vfl_rf
clear_memory()
# Out:
# ➡ [⌛] Training VFL-Stacked Random Forest...
#    [⌛] Fitting Stage 1 Classifier on FULL DATASET: 3,500,800 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 19.7 seconds.
#    [⌛] Fitting Stage 1 Classifier on FULL DATASET: 3,500,800 rows... (Please wait)
#    [✅] Stage 1 Classifier complete in 16.2 seconds.
#    [⌛] Fitting Stage 2 Regressor on FULL DATASET: 1,128,881 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 25.1 seconds.
#    [⌛] Fitting Stage 2 Regressor on FULL DATASET: 1,128,881 rows... (Please wait)
#    [✅] Stage 2 Regressor complete in 35.2 seconds.

# %% [markdown]
# The VFL-stacked Random Forest trains four local models: UE classifier, RU classifier, UE regressor, and RU regressor. The printed row counts correspond to the base-user portion of the training split. The remaining meta-user portion is used internally to train the coordinator models.
#
# This setup allows the Random Forest baseline to be evaluated in both centralized and vertically partitioned forms. Comparing the centralized RF and VFL-stacked RF later shows how much performance is affected when raw features are split between UE-side and RU-side models.

# %% [markdown]
# ## 13. Linear VFL Baseline
#
# The assignment requires a Vertical FL setup using a combined Linear Regressor for throughput prediction. To satisfy this requirement, this baseline trains a simple two-stage linear model using the combined UE-side and RU-side feature groups.
#
# The first stage uses Logistic Regression to predict whether a user is active or idle. The second stage uses Ridge Regression to predict `log(1 + Throughput)` for active-throughput samples.
#
# This model provides a simple linear reference point for the VFL experiments. It helps show whether the more complex VFL-stacked Random Forest and Neural Network models provide a meaningful improvement over a linear coordinator-style baseline.

# %%
print("➡ [⌛] Training Linear VFL Baseline...")
linear_vfl = train_linear_vfl_baseline(rf_train_raw, list(ue_features) + list(ru_features), target, CFG)

joblib.dump(linear_vfl, os.path.join(working_dir, "linear_vfl.joblib"))

del linear_vfl
clear_memory()
# Out:
# ➡ [⌛] Training Linear VFL Baseline...

# %% [markdown]
# The Linear VFL baseline is intentionally simpler than the Random Forest and Neural Network models. Its purpose is not to maximize performance, but to provide a required combined linear reference model for the vertically partitioned feature setting.

# %% [markdown]
# ## 14. Centralized Neural Network: LSTM + MLP
#
# The second required model for the base task is a Neural Network. In this notebook, the centralized Neural Network is implemented as an LSTM + MLP model.
#
# The LSTM branch processes dynamic time-varying features such as SINR, BLER, radio-unit load, movement, position, effective signal quality, and crowd density. The MLP branch processes static or contextual features such as the one-hot encoded traffic-state variables.
#
# Like the Random Forest model, the Neural Network uses a two-stage setup: an active/idle classifier followed by a log-throughput regressor for active samples. This design handles the zero-heavy nature of the throughput target while allowing the model to learn temporal patterns from each user's sequence of observations.

# %% [markdown]
# ### 14.1 Neural-Network Data Preparation
#
# The LSTM + MLP model requires standardized numeric inputs. To avoid data leakage, the scalers are fitted on the training set only and then applied to the validation and test sets.
#
# Dynamic features are scaled separately from static/contextual features. In the final feature set, the static features are one-hot encoded traffic-state columns, so they do not require additional scaling.

# %%
dyn_trained = [c for c in dynamic_cols if c in best_feats]
sta_trained = [c for c in static_cols if c in best_feats]
cont_sta    = [c for c in sta_trained if not c.startswith("State_")]

train_ann = rf_train_raw.copy()
val_ann   = rf_val_raw.copy()
test_ann  = rf_test_raw.copy()

# Fit and apply transform paths
ds = StandardScaler()
train_ann[dyn_trained] = ds.fit_transform(train_ann[dyn_trained])
val_ann[dyn_trained]   = ds.transform(val_ann[dyn_trained])
test_ann[dyn_trained]  = ds.transform(test_ann[dyn_trained])

if cont_sta:
    ss = StandardScaler()
    train_ann[cont_sta] = ss.fit_transform(train_ann[cont_sta])
    val_ann[cont_sta]   = ss.transform(val_ann[cont_sta])
    test_ann[cont_sta]  = ss.transform(test_ann[cont_sta])
else:
    ss = None

joblib.dump(ds, os.path.join(working_dir, "scaler_dynamic.joblib"))
if ss:
    joblib.dump(ss, os.path.join(working_dir, "scaler_static.joblib"))
    
print(f"dyn feats: {dyn_trained}, stat feats: {sta_trained}")
print("[✅] Deep Learning datasets scaled and cached successfully.")
# Out:
# dyn feats: ['SINR_UL', 'BLER', 'SINR_UL_q90', 'BLER_q10', 'Log_Effective_Signal_Robust', 'RU_Current_Load', 'X_meters', 'Y_meters', 'Velocity', 'Crowd_Density_5m'], stat feats: ['State_0', 'State_1', 'State_2', 'State_3', 'State_4', 'State_5']
# [✅] Deep Learning datasets scaled and cached successfully.

# %% [markdown]
# The final neural-network input contains ten dynamic features and six static/contextual traffic-state features. The dynamic features are standardized using training-set statistics only, and the same transformation is applied to validation and test data. This keeps the neural-network preprocessing consistent without allowing information from validation or test sets to influence training.

# %% [markdown]
# ### 14.2 LSTM + MLP Hyperparameter Tuning
#
# The LSTM + MLP hyperparameters are tuned using the same training-user subset and GroupKFold strategy used for the Random Forest tuning. The folds are grouped by `User_ID`, which prevents samples from the same user appearing in both the tuning-train and tuning-validation folds.
#
# The tuning compares a small runtime-safe grid of hidden dimensions, learning rates, and dropout values. The goal is not exhaustive optimization, but to select a reasonable Neural Network configuration while keeping training feasible under Kaggle/Colab limits.
#
# The natural active/idle distribution is preserved. Instead of undersampling rows, the classifier stage uses a positive-class weight during training to account for class imbalance.

# %%
# LSTM + MLP tuning config: fewer epochs and a user subset for runtime control
# The natural row distribution is preserved; classifier imbalance is handled with pos_weight.

tune_ann_df = train_ann[train_ann['User_ID'].isin(subset_cv_users)].copy()

dl_tune_cfg = copy.deepcopy(CFG)
dl_tune_cfg.epochs = 15
dl_tune_cfg.batch_size = 128

dl_param_grid = [
    {'lstm_hidden': 32, 'mlp_hidden': 16, 'lr': 1e-3, 'dropout': 0.2},
    {'lstm_hidden': 64, 'mlp_hidden': 32, 'lr': 5e-4, 'dropout': 0.3},
    {'lstm_hidden': 64, 'mlp_hidden': 16, 'lr': 1e-3, 'dropout': 0.4},
]

dl_best_score = -np.inf
dl_best_params = None
dl_best_threshold = 0.5

print("\n--- LSTM+MLP Hyperparameter Tuning (GroupKFold, train only) ---")
for params in dl_param_grid:
    fold_scores = []
    for fold, (train_idx, val_idx) in enumerate(kf.split(tune_ann_df, groups=tune_ann_df['User_ID'])):
        tr_ann = tune_ann_df.iloc[train_idx].copy()
        vl_ann = tune_ann_df.iloc[val_idx].copy()
        
        cfg_tmp = copy.deepcopy(dl_tune_cfg)
        for k, v in params.items():
            setattr(cfg_tmp, k, v)
        
        bundle = train_centralized_dl(tr_ann, vl_ann, dyn_trained, sta_trained, target, user_col, cfg_tmp)
        pred, y_val, _ = predict_centralized_dl(bundle, vl_ann, target, user_col, cfg_tmp)
        r2 = r2_score(np.log1p(y_val), np.log1p(pred))
        fold_scores.append(r2)
        
        del tr_ann, vl_ann, pred, y_val, cfg_tmp
        clear_memory()
    avg, std = np.mean(fold_scores), np.std(fold_scores)
    print(f"Params {params} → R²_log = {avg:.4f} ± {std:.4f}")
    if avg > dl_best_score:
        dl_best_score = avg
        dl_best_params = params
        dl_best_threshold = bundle['threshold']   # from last fold, okay for estimation
        del bundle
        clear_memory()

print(f"Best LSTM params: {dl_best_params}, CV R²_log = {dl_best_score:.4f}")
for k, v in dl_best_params.items():
    setattr(CFG, k, v)
# (Optional) store the best threshold for final evaluation
CFG.dl_best_threshold = dl_best_threshold
# Out:
# --- LSTM+MLP Hyperparameter Tuning (GroupKFold, train only) ---
#
# [TRAINING] model
# Epoch 01 | train_loss=0.12104 | val_loss=0.00304
# Epoch 02 | train_loss=0.00201 | val_loss=0.00186
# Epoch 03 | train_loss=0.00121 | val_loss=0.00165
# Epoch 04 | train_loss=0.00124 | val_loss=0.00173
# Epoch 05 | train_loss=0.00110 | val_loss=0.00156
# Epoch 06 | train_loss=0.00098 | val_loss=0.00149
# Epoch 07 | train_loss=0.00098 | val_loss=0.00140
# Epoch 08 | train_loss=0.00091 | val_loss=0.00134
# Epoch 09 | train_loss=0.00081 | val_loss=0.00166
# Epoch 10 | train_loss=0.00078 | val_loss=0.00134
# Epoch 11 | train_loss=0.00069 | val_loss=0.00132
# Epoch 12 | train_loss=0.00081 | val_loss=0.00135
# Epoch 13 | train_loss=0.00075 | val_loss=0.00159
# Epoch 14 | train_loss=0.00104 | val_loss=0.00150
# Epoch 15 | train_loss=0.00070 | val_loss=0.00162
# [model] Early stopping at epoch 15. Best val_loss=0.00132
#
# [TRAINING] model
# Epoch 01 | train_loss=0.68715 | val_loss=0.41358
# Epoch 02 | train_loss=0.43826 | val_loss=0.39798
# Epoch 03 | train_loss=0.42995 | val_loss=0.38714
# Epoch 04 | train_loss=0.41899 | val_loss=0.38961
# Epoch 05 | train_loss=0.41543 | val_loss=0.38484
# Epoch 06 | train_loss=0.41254 | val_loss=0.38924
# Epoch 07 | train_loss=0.40829 | val_loss=0.39373
# Epoch 08 | train_loss=0.40776 | val_loss=0.38776
# Epoch 09 | train_loss=0.40500 | val_loss=0.38335
# Epoch 10 | train_loss=0.40174 | val_loss=0.38671
# Epoch 11 | train_loss=0.40025 | val_loss=0.38354
# Epoch 12 | train_loss=0.39804 | val_loss=0.39509
# Epoch 13 | train_loss=0.39589 | val_loss=0.37844
# Epoch 14 | train_loss=0.39413 | val_loss=0.38715
# Epoch 15 | train_loss=0.38889 | val_loss=0.38938
#
# [TRAINING] model
# Epoch 01 | train_loss=0.13164 | val_loss=0.00112
# Epoch 02 | train_loss=0.00344 | val_loss=0.00054
# Epoch 03 | train_loss=0.00207 | val_loss=0.00043
# Epoch 04 | train_loss=0.00185 | val_loss=0.00040
# Epoch 05 | train_loss=0.00133 | val_loss=0.00038
# Epoch 06 | train_loss=0.00151 | val_loss=0.00045
# Epoch 07 | train_loss=0.00134 | val_loss=0.00038
# Epoch 08 | train_loss=0.00124 | val_loss=0.00037
# Epoch 09 | train_loss=0.00125 | val_loss=0.00038
# Epoch 10 | train_loss=0.00116 | val_loss=0.00036
# Epoch 11 | train_loss=0.00107 | val_loss=0.00042
# Epoch 12 | train_loss=0.00114 | val_loss=0.00038
# Epoch 13 | train_loss=0.00111 | val_loss=0.00038
# Epoch 14 | train_loss=0.00112 | val_loss=0.00039
# [model] Early stopping at epoch 14. Best val_loss=0.00036
#
# [TRAINING] model
# Epoch 01 | train_loss=0.63808 | val_loss=0.43005
# Epoch 02 | train_loss=0.43184 | val_loss=0.41971
# Epoch 03 | train_loss=0.42001 | val_loss=0.42679
# Epoch 04 | train_loss=0.41440 | val_loss=0.42608
# Epoch 05 | train_loss=0.40761 | val_loss=0.42012
# Epoch 06 | train_loss=0.40732 | val_loss=0.41362
# Epoch 07 | train_loss=0.40138 | val_loss=0.41753
# Epoch 08 | train_loss=0.40249 | val_loss=0.41918
# Epoch 09 | train_loss=0.39810 | val_loss=0.41026
# Epoch 10 | train_loss=0.39738 | val_loss=0.41427
# Epoch 11 | train_loss=0.39311 | val_loss=0.41079
# Epoch 12 | train_loss=0.39306 | val_loss=0.41100
# Epoch 13 | train_loss=0.39058 | val_loss=0.41480
# [model] Early stopping at epoch 13. Best val_loss=0.41026
#
# [TRAINING] model
# Epoch 01 | train_loss=0.12379 | val_loss=0.00205
# Epoch 02 | train_loss=0.00253 | val_loss=0.00121
# Epoch 03 | train_loss=0.00151 | val_loss=0.00104
# Epoch 04 | train_loss=0.00119 | val_loss=0.00097
# Epoch 05 | train_loss=0.00104 | val_loss=0.00087
# Epoch 06 | train_loss=0.00108 | val_loss=0.00097
# Epoch 07 | train_loss=0.00104 | val_loss=0.00085
# Epoch 08 | train_loss=0.00098 | val_loss=0.00092
# Epoch 09 | train_loss=0.00103 | val_loss=0.00084
# Epoch 10 | train_loss=0.00090 | val_loss=0.00088
# Epoch 11 | train_loss=0.00101 | val_loss=0.00094
# Epoch 12 | train_loss=0.00098 | val_loss=0.00080
# Epoch 13 | train_loss=0.00084 | val_loss=0.00109
# Epoch 14 | train_loss=0.00083 | val_loss=0.00081
# Epoch 15 | train_loss=0.00087 | val_loss=0.00085
#
# [TRAINING] model
# Epoch 01 | train_loss=0.72225 | val_loss=0.40939
# Epoch 02 | train_loss=0.43475 | val_loss=0.40732
# Epoch 03 | train_loss=0.41835 | val_loss=0.42463
# Epoch 04 | train_loss=0.41379 | val_loss=0.39986
# Epoch 05 | train_loss=0.40947 | val_loss=0.40776
# Epoch 06 | train_loss=0.40529 | val_loss=0.40992
# Epoch 07 | train_loss=0.40038 | val_loss=0.39754
# Epoch 08 | train_loss=0.39918 | val_loss=0.39955
# Epoch 09 | train_loss=0.39567 | val_loss=0.39646
# Epoch 10 | train_loss=0.39436 | val_loss=0.39602
# Epoch 11 | train_loss=0.39343 | val_loss=0.39797
# Epoch 12 | train_loss=0.39100 | val_loss=0.39714
# Epoch 13 | train_loss=0.38971 | val_loss=0.39754
# Epoch 14 | train_loss=0.38781 | val_loss=0.39754
# [model] Early stopping at epoch 14. Best val_loss=0.39602
# Params {'lstm_hidden': 32, 'mlp_hidden': 16, 'lr': 0.001, 'dropout': 0.2} → R²_log = 0.7958 ± 0.0043
#
# [TRAINING] model
# Epoch 01 | train_loss=0.16467 | val_loss=0.01004
# Epoch 02 | train_loss=0.00521 | val_loss=0.00492
# Epoch 03 | train_loss=0.00240 | val_loss=0.00261
# Epoch 04 | train_loss=0.00152 | val_loss=0.00185
# Epoch 05 | train_loss=0.00111 | val_loss=0.00158
# Epoch 06 | train_loss=0.00098 | val_loss=0.00143
# Epoch 07 | train_loss=0.00093 | val_loss=0.00159
# Epoch 08 | train_loss=0.00084 | val_loss=0.00150
# Epoch 09 | train_loss=0.00087 | val_loss=0.00137
# Epoch 10 | train_loss=0.00082 | val_loss=0.00163
# Epoch 11 | train_loss=0.00078 | val_loss=0.00130
# Epoch 12 | train_loss=0.00087 | val_loss=0.00138
# Epoch 13 | train_loss=0.00071 | val_loss=0.00148
# Epoch 14 | train_loss=0.00074 | val_loss=0.00151
# Epoch 15 | train_loss=0.00070 | val_loss=0.00124
#
# [TRAINING] model
# Epoch 01 | train_loss=0.95142 | val_loss=0.44014
# Epoch 02 | train_loss=0.49558 | val_loss=0.40306
# Epoch 03 | train_loss=0.48107 | val_loss=0.41924
# Epoch 04 | train_loss=0.47137 | val_loss=0.40840
# Epoch 05 | train_loss=0.45832 | val_loss=0.39350
# Epoch 06 | train_loss=0.45669 | val_loss=0.39007
# Epoch 07 | train_loss=0.45399 | val_loss=0.39080
# Epoch 08 | train_loss=0.45606 | val_loss=0.39170
# Epoch 09 | train_loss=0.44722 | val_loss=0.39217
# Epoch 10 | train_loss=0.44722 | val_loss=0.38755
# Epoch 11 | train_loss=0.44263 | val_loss=0.39118
# Epoch 12 | train_loss=0.43709 | val_loss=0.38440
# Epoch 13 | train_loss=0.43295 | val_loss=0.38676
# Epoch 14 | train_loss=0.43152 | val_loss=0.39275
# Epoch 15 | train_loss=0.42997 | val_loss=0.39505
#
# [TRAINING] model
# Epoch 01 | train_loss=0.16625 | val_loss=0.00328
# Epoch 02 | train_loss=0.00663 | val_loss=0.00091
# Epoch 03 | train_loss=0.00316 | val_loss=0.00058
# Epoch 04 | train_loss=0.00229 | val_loss=0.00044
# Epoch 05 | train_loss=0.00175 | val_loss=0.00040
# Epoch 06 | train_loss=0.00146 | val_loss=0.00046
# Epoch 07 | train_loss=0.00145 | val_loss=0.00039
# Epoch 08 | train_loss=0.00144 | val_loss=0.00041
# Epoch 09 | train_loss=0.00133 | val_loss=0.00039
# Epoch 10 | train_loss=0.00116 | val_loss=0.00040
# Epoch 11 | train_loss=0.00121 | val_loss=0.00045
# [model] Early stopping at epoch 11. Best val_loss=0.00039
#
# [TRAINING] model
# Epoch 01 | train_loss=0.88240 | val_loss=0.45533
# Epoch 02 | train_loss=0.46981 | val_loss=0.42711
# Epoch 03 | train_loss=0.45096 | val_loss=0.42138
# Epoch 04 | train_loss=0.44708 | val_loss=0.41718
# Epoch 05 | train_loss=0.44020 | val_loss=0.41506
# Epoch 06 | train_loss=0.43588 | val_loss=0.41204
# Epoch 07 | train_loss=0.42988 | val_loss=0.41029
# Epoch 08 | train_loss=0.43063 | val_loss=0.41856
# Epoch 09 | train_loss=0.42494 | val_loss=0.41582
# Epoch 10 | train_loss=0.42233 | val_loss=0.40953
# Epoch 11 | train_loss=0.42381 | val_loss=0.40147
# Epoch 12 | train_loss=0.42042 | val_loss=0.40776
# Epoch 13 | train_loss=0.41579 | val_loss=0.41879
# Epoch 14 | train_loss=0.41576 | val_loss=0.41033
# Epoch 15 | train_loss=0.41261 | val_loss=0.40959
# [model] Early stopping at epoch 15. Best val_loss=0.40147
#
# [TRAINING] model
# Epoch 01 | train_loss=0.17220 | val_loss=0.00492
# Epoch 02 | train_loss=0.00511 | val_loss=0.00240
# Epoch 03 | train_loss=0.00271 | val_loss=0.00155
# Epoch 04 | train_loss=0.00173 | val_loss=0.00115
# Epoch 05 | train_loss=0.00151 | val_loss=0.00111
# Epoch 06 | train_loss=0.00127 | val_loss=0.00092
# Epoch 07 | train_loss=0.00113 | val_loss=0.00096
# Epoch 08 | train_loss=0.00116 | val_loss=0.00098
# Epoch 09 | train_loss=0.00109 | val_loss=0.00087
# Epoch 10 | train_loss=0.00088 | val_loss=0.00088
# Epoch 11 | train_loss=0.00102 | val_loss=0.00101
# Epoch 12 | train_loss=0.00105 | val_loss=0.00111
# Epoch 13 | train_loss=0.00095 | val_loss=0.00082
# Epoch 14 | train_loss=0.00084 | val_loss=0.00081
# Epoch 15 | train_loss=0.00093 | val_loss=0.00083
#
# [TRAINING] model
# Epoch 01 | train_loss=0.75314 | val_loss=0.43042
# Epoch 02 | train_loss=0.45861 | val_loss=0.41023
# Epoch 03 | train_loss=0.44411 | val_loss=0.41177
# Epoch 04 | train_loss=0.43619 | val_loss=0.41042
# Epoch 05 | train_loss=0.43556 | val_loss=0.40547
# Epoch 06 | train_loss=0.42960 | val_loss=0.41437
# Epoch 07 | train_loss=0.42575 | val_loss=0.40339
# Epoch 08 | train_loss=0.42020 | val_loss=0.40892
# Epoch 09 | train_loss=0.42271 | val_loss=0.41057
# Epoch 10 | train_loss=0.41776 | val_loss=0.40606
# Epoch 11 | train_loss=0.41192 | val_loss=0.40938
# [model] Early stopping at epoch 11. Best val_loss=0.40339
# Params {'lstm_hidden': 64, 'mlp_hidden': 32, 'lr': 0.0005, 'dropout': 0.3} → R²_log = 0.7949 ± 0.0073
#
# [TRAINING] model
# Epoch 01 | train_loss=0.15108 | val_loss=0.00426
# Epoch 02 | train_loss=0.01031 | val_loss=0.00237
# Epoch 03 | train_loss=0.00700 | val_loss=0.00178
# Epoch 04 | train_loss=0.00533 | val_loss=0.00320
# Epoch 05 | train_loss=0.00523 | val_loss=0.00176
# Epoch 06 | train_loss=0.00489 | val_loss=0.00145
# Epoch 07 | train_loss=0.00533 | val_loss=0.00189
# Epoch 08 | train_loss=0.00457 | val_loss=0.00207
# Epoch 09 | train_loss=0.00478 | val_loss=0.00178
# Epoch 10 | train_loss=0.00459 | val_loss=0.00148
# [model] Early stopping at epoch 10. Best val_loss=0.00145
#
# [TRAINING] model
# Epoch 01 | train_loss=0.74470 | val_loss=0.42713
# Epoch 02 | train_loss=0.48210 | val_loss=0.39695
# Epoch 03 | train_loss=0.46828 | val_loss=0.38913
# Epoch 04 | train_loss=0.46431 | val_loss=0.40131
# Epoch 05 | train_loss=0.45540 | val_loss=0.39563
# Epoch 06 | train_loss=0.44933 | val_loss=0.39512
# Epoch 07 | train_loss=0.44181 | val_loss=0.39045
# [model] Early stopping at epoch 7. Best val_loss=0.38913
#
# [TRAINING] model
# Epoch 01 | train_loss=0.13884 | val_loss=0.00132
# Epoch 02 | train_loss=0.01154 | val_loss=0.00052
# Epoch 03 | train_loss=0.00593 | val_loss=0.00048
# Epoch 04 | train_loss=0.00600 | val_loss=0.00047
# Epoch 05 | train_loss=0.00564 | val_loss=0.00042
# Epoch 06 | train_loss=0.00508 | val_loss=0.00049
# Epoch 07 | train_loss=0.00514 | val_loss=0.00042
# Epoch 08 | train_loss=0.00560 | val_loss=0.00046
# Epoch 09 | train_loss=0.00481 | val_loss=0.00052
# [model] Early stopping at epoch 9. Best val_loss=0.00042
#
# [TRAINING] model
# Epoch 01 | train_loss=0.71607 | val_loss=0.45607
# Epoch 02 | train_loss=0.47260 | val_loss=0.41932
# Epoch 03 | train_loss=0.45924 | val_loss=0.42208
# Epoch 04 | train_loss=0.45273 | val_loss=0.42093
# Epoch 05 | train_loss=0.44123 | val_loss=0.41835
# Epoch 06 | train_loss=0.43987 | val_loss=0.42351
# Epoch 07 | train_loss=0.43177 | val_loss=0.42272
# Epoch 08 | train_loss=0.42656 | val_loss=0.42207
# Epoch 09 | train_loss=0.42289 | val_loss=0.41442
# Epoch 10 | train_loss=0.42088 | val_loss=0.40892
# Epoch 11 | train_loss=0.41204 | val_loss=0.41546
# Epoch 12 | train_loss=0.40715 | val_loss=0.41514
# Epoch 13 | train_loss=0.40388 | val_loss=0.41444
# Epoch 14 | train_loss=0.39968 | val_loss=0.41788
# [model] Early stopping at epoch 14. Best val_loss=0.40892
#
# [TRAINING] model
# Epoch 01 | train_loss=0.13298 | val_loss=0.00377
# Epoch 02 | train_loss=0.00676 | val_loss=0.00132
# Epoch 03 | train_loss=0.00428 | val_loss=0.00109
# Epoch 04 | train_loss=0.00299 | val_loss=0.00105
# Epoch 05 | train_loss=0.00324 | val_loss=0.00109
# Epoch 06 | train_loss=0.00253 | val_loss=0.00109
# Epoch 07 | train_loss=0.00228 | val_loss=0.00105
# Epoch 08 | train_loss=0.00251 | val_loss=0.00138
# [model] Early stopping at epoch 8. Best val_loss=0.00105
#
# [TRAINING] model
# Epoch 01 | train_loss=0.77326 | val_loss=0.41634
# Epoch 02 | train_loss=0.51978 | val_loss=0.42135
# Epoch 03 | train_loss=0.50192 | val_loss=0.43020
# Epoch 04 | train_loss=0.48700 | val_loss=0.42083
# Epoch 05 | train_loss=0.47849 | val_loss=0.40907
# Epoch 06 | train_loss=0.46215 | val_loss=0.40390
# Epoch 07 | train_loss=0.44784 | val_loss=0.41635
# Epoch 08 | train_loss=0.43880 | val_loss=0.40897
# Epoch 09 | train_loss=0.43087 | val_loss=0.41446
# Epoch 10 | train_loss=0.42052 | val_loss=0.41807
# [model] Early stopping at epoch 10. Best val_loss=0.40390
# Params {'lstm_hidden': 64, 'mlp_hidden': 16, 'lr': 0.001, 'dropout': 0.4} → R²_log = 0.7928 ± 0.0060
# Best LSTM params: {'lstm_hidden': 32, 'mlp_hidden': 16, 'lr': 0.001, 'dropout': 0.2}, CV R²_log = 0.7958

# %% [markdown]
# The LSTM + MLP tuning selected `lstm_hidden=32`, `mlp_hidden=16`, `lr=0.001`, and `dropout=0.2`, with an average cross-validation log R² of 0.7958.
#
# The larger hidden-size configurations did not improve validation performance. This suggests that the smaller model is sufficient for this feature set and is less computationally expensive. The selected configuration is therefore used for the final centralized Neural Network and VFL Neural Network experiments.

# %% [markdown]
# ### 14.3 Centralized LSTM + MLP Two-Stage Training
#
# The centralized Neural Network replaces the Random Forest with a hybrid **LSTM + MLP** architecture.
#
# - **LSTM branch:** processes 16-window sequences of dynamic features, such as SINR, BLER, radio-unit load, position, movement, effective signal quality, and crowd density.
# - **MLP branch:** processes the static/contextual features at the final time step, mainly the one-hot encoded traffic-state variables.
# - **Fusion head:** combines the LSTM and MLP representations to produce the final classifier or regressor output.
#
# The same two-stage logic used for Random Forest is preserved. The first neural network predicts whether the user is active or idle, and the second neural network predicts `log(1 + Throughput)` for active-throughput samples.
#
# This architecture allows the model to learn temporal patterns in radio quality, mobility, and load that are not explicitly represented in a standard row-based Random Forest.

# %%
print("➡ [⌛] Training Centralized LSTM+MLP (Two-Stage Pipeline)...")
central_dl = train_centralized_dl(train_ann, val_ann, dyn_trained, sta_trained, target, user_col="User_ID", cfg=CFG)

# Save neural weights & structural parameters separately
torch.save(central_dl["cls_model"].state_dict(), os.path.join(working_dir, "central_dl_cls.pt"))
torch.save(central_dl["reg_model"].state_dict(), os.path.join(working_dir, "central_dl_reg.pt"))
joblib.dump({
    "threshold": central_dl["threshold"],
    "dynamic_cols": central_dl["dynamic_cols"],
    "static_cols": central_dl["static_cols"]
}, os.path.join(working_dir, "central_dl_meta.joblib"))

del central_dl
clear_memory()
# Out:
# ➡ [⌛] Training Centralized LSTM+MLP (Two-Stage Pipeline)...
#
# [TRAINING] model
# Epoch 01 | train_loss=0.02155 | val_loss=0.00081
# Epoch 02 | train_loss=0.00113 | val_loss=0.00095
# Epoch 03 | train_loss=0.00104 | val_loss=0.00085
# Epoch 04 | train_loss=0.00103 | val_loss=0.00078
# Epoch 05 | train_loss=0.00097 | val_loss=0.00076
# Epoch 06 | train_loss=0.00098 | val_loss=0.00081
# Epoch 07 | train_loss=0.00096 | val_loss=0.00077
# Epoch 08 | train_loss=0.00096 | val_loss=0.00076
# Epoch 09 | train_loss=0.00092 | val_loss=0.00076
# [model] Early stopping at epoch 9. Best val_loss=0.00076
#
# [TRAINING] model
# Epoch 01 | train_loss=0.47130 | val_loss=0.39488
# Epoch 02 | train_loss=0.40079 | val_loss=0.39647
# Epoch 03 | train_loss=0.39070 | val_loss=0.38974
# Epoch 04 | train_loss=0.38304 | val_loss=0.38526
# Epoch 05 | train_loss=0.37847 | val_loss=0.38375
# Epoch 06 | train_loss=0.37636 | val_loss=0.38396
# Epoch 07 | train_loss=0.37421 | val_loss=0.38320
# Epoch 08 | train_loss=0.37365 | val_loss=0.38293
# Epoch 09 | train_loss=0.37222 | val_loss=0.38183
# Epoch 10 | train_loss=0.37178 | val_loss=0.38017
# Epoch 11 | train_loss=0.37137 | val_loss=0.38377
# Epoch 12 | train_loss=0.37062 | val_loss=0.38111
# Epoch 13 | train_loss=0.37023 | val_loss=0.38465
# Epoch 14 | train_loss=0.36970 | val_loss=0.38055
# [model] Early stopping at epoch 14. Best val_loss=0.38017

# %% [markdown]
# ## 15. VFL Neural Network: Stacked LSTM + MLP
#
# The VFL Neural Network extends the vertical feature-splitting idea to the LSTM + MLP architecture. Instead of training one centralized neural network on all features, separate local neural models are trained for the UE-side and RU-side feature groups.
#
# - **UE-side model:** uses user-position, movement, and traffic-state/context features.
# - **RU-side model:** uses radio-quality, radio-load, effective-signal, and crowd-density features.
# - **Coordinator model:** combines the outputs of the UE and RU models using Logistic Regression for the active/idle stage and Ridge Regression for the log-throughput stage.
#
# The same base/meta user split from the VFL Random Forest experiment is reused. UE and RU local models are trained on the base users, and the coordinator is trained on local-model outputs from the meta users.
#
# This design tests whether vertically partitioned neural models can preserve most of the predictive performance of the centralized LSTM + MLP model without directly combining raw UE and RU feature columns.

# %%
# Load the same base/meta user partition used for the VFL Random Forest
base_users = np.load(os.path.join(working_dir, "vfl_base_users.npy"))
meta_users = np.load(os.path.join(working_dir, "vfl_meta_users.npy"))

print("➡ [⌛] Training VFL-Stacked LSTM+MLP Model...")
vfl_dl = train_vfl_stacked_dl(
    train_ann, val_ann,
    [c for c in dyn_trained if c in ue_features],
    [c for c in sta_trained if c in ue_features],
    [c for c in dyn_trained if c in ru_features],
    [c for c in sta_trained if c in ru_features],
    target, base_users, meta_users,
    user_col="User_ID", cfg=CFG
)

# Persist all sub-party states and meta-aggregator weights
torch.save(vfl_dl["ue_cls"].state_dict(), os.path.join(working_dir, "vfl_dl_ue_cls.pt"))
torch.save(vfl_dl["ru_cls"].state_dict(), os.path.join(working_dir, "vfl_dl_ru_cls.pt"))
torch.save(vfl_dl["ue_reg"].state_dict(), os.path.join(working_dir, "vfl_dl_ue_reg.pt"))
torch.save(vfl_dl["ru_reg"].state_dict(), os.path.join(working_dir, "vfl_dl_ru_reg.pt"))
joblib.dump({
    "coord_clf": vfl_dl["coord_clf"],
    "coord_reg": vfl_dl["coord_reg"],
    "coord_threshold": vfl_dl.get("coord_threshold", 0.5),
    "ue_threshold": vfl_dl.get("ue_threshold", 0.5),
    "ru_threshold": vfl_dl.get("ru_threshold", 0.5),
    "ue_dyn": vfl_dl["ue_dyn"],
    "ue_sta": vfl_dl["ue_sta"],
    "ru_dyn": vfl_dl["ru_dyn"],
    "ru_sta": vfl_dl["ru_sta"]
}, os.path.join(working_dir, "vfl_dl_coord.joblib"))

del vfl_dl
clear_memory()
# Out:
# ➡ [⌛] Training VFL-Stacked LSTM+MLP Model...
# [VFL-DL] Classifier windows: total=851,200, pos=274,471, neg=576,729
#
# [TRAINING] UE_CLS
# Epoch 01 | train_loss=0.03732 | val_loss=0.00197
# Epoch 02 | train_loss=0.00323 | val_loss=0.00188
# Epoch 03 | train_loss=0.00305 | val_loss=0.00187
# Epoch 04 | train_loss=0.00301 | val_loss=0.00196
# Epoch 05 | train_loss=0.00303 | val_loss=0.00200
# Epoch 06 | train_loss=0.00294 | val_loss=0.00186
# Epoch 07 | train_loss=0.00294 | val_loss=0.00194
# Epoch 08 | train_loss=0.00290 | val_loss=0.00189
# Epoch 09 | train_loss=0.00295 | val_loss=0.00181
# Epoch 10 | train_loss=0.00289 | val_loss=0.00181
# Epoch 11 | train_loss=0.00280 | val_loss=0.00176
# Epoch 12 | train_loss=0.00275 | val_loss=0.00203
# Epoch 13 | train_loss=0.00275 | val_loss=0.00181
# Epoch 14 | train_loss=0.00275 | val_loss=0.00177
# Epoch 15 | train_loss=0.00277 | val_loss=0.00173
# Epoch 16 | train_loss=0.00273 | val_loss=0.00176
# Epoch 17 | train_loss=0.00275 | val_loss=0.00178
# Epoch 18 | train_loss=0.00279 | val_loss=0.00187
# Epoch 19 | train_loss=0.00272 | val_loss=0.00175
# [UE_CLS] Early stopping at epoch 19. Best val_loss=0.00173
#
# [TRAINING] UE_REG
# Epoch 01 | train_loss=0.62713 | val_loss=0.52957
# Epoch 02 | train_loss=0.53799 | val_loss=0.52743
# Epoch 03 | train_loss=0.52312 | val_loss=0.52005
# Epoch 04 | train_loss=0.50989 | val_loss=0.52070
# Epoch 05 | train_loss=0.50094 | val_loss=0.51685
# Epoch 06 | train_loss=0.49392 | val_loss=0.51385
# Epoch 07 | train_loss=0.48968 | val_loss=0.51127
# Epoch 08 | train_loss=0.48795 | val_loss=0.50827
# Epoch 09 | train_loss=0.48698 | val_loss=0.50666
# Epoch 10 | train_loss=0.48650 | val_loss=0.50845
# Epoch 11 | train_loss=0.48531 | val_loss=0.50937
# Epoch 12 | train_loss=0.48445 | val_loss=0.50883
# Epoch 13 | train_loss=0.48327 | val_loss=0.50705
# [UE_REG] Early stopping at epoch 13. Best val_loss=0.50666
#
# [TRAINING] RU_CLS
# Epoch 01 | train_loss=0.34017 | val_loss=0.20310
# Epoch 02 | train_loss=0.19607 | val_loss=0.02381
# Epoch 03 | train_loss=0.14978 | val_loss=0.07904
# Epoch 04 | train_loss=0.12223 | val_loss=0.02204
# Epoch 05 | train_loss=0.11632 | val_loss=0.01092
# Epoch 06 | train_loss=0.08726 | val_loss=0.03416
# Epoch 07 | train_loss=0.03459 | val_loss=0.00083
# Epoch 08 | train_loss=0.00076 | val_loss=0.00078
# Epoch 09 | train_loss=0.07974 | val_loss=0.10498
# Epoch 10 | train_loss=0.05299 | val_loss=0.00193
# Epoch 11 | train_loss=0.00766 | val_loss=0.00077
# Epoch 12 | train_loss=0.00074 | val_loss=0.00076
# Epoch 13 | train_loss=0.10559 | val_loss=0.00080
# Epoch 14 | train_loss=0.02385 | val_loss=0.00078
# Epoch 15 | train_loss=0.04114 | val_loss=0.00109
# Epoch 16 | train_loss=0.03400 | val_loss=0.00076
# Epoch 17 | train_loss=0.03996 | val_loss=0.00076
# Epoch 18 | train_loss=0.00072 | val_loss=0.00076
# Epoch 19 | train_loss=0.02745 | val_loss=0.11340
# Epoch 20 | train_loss=0.03358 | val_loss=0.00078
# [RU_CLS] Early stopping at epoch 20. Best val_loss=0.00076
#
# [TRAINING] RU_REG
# Epoch 01 | train_loss=0.46739 | val_loss=0.40841
# Epoch 02 | train_loss=0.40169 | val_loss=0.39276
# Epoch 03 | train_loss=0.39364 | val_loss=0.38856
# Epoch 04 | train_loss=0.38805 | val_loss=0.38672
# Epoch 05 | train_loss=0.38391 | val_loss=0.38613
# Epoch 06 | train_loss=0.38158 | val_loss=0.38687
# Epoch 07 | train_loss=0.37934 | val_loss=0.38495
# Epoch 08 | train_loss=0.37779 | val_loss=0.38345
# Epoch 09 | train_loss=0.37691 | val_loss=0.38793
# Epoch 10 | train_loss=0.37656 | val_loss=0.38382
# Epoch 11 | train_loss=0.37588 | val_loss=0.38433
# Epoch 12 | train_loss=0.37504 | val_loss=0.38187
# Epoch 13 | train_loss=0.37473 | val_loss=0.38528
# Epoch 14 | train_loss=0.37446 | val_loss=0.38368
# Epoch 15 | train_loss=0.37434 | val_loss=0.38175
# Epoch 16 | train_loss=0.37376 | val_loss=0.38327
# Epoch 17 | train_loss=0.37327 | val_loss=0.38656
# Epoch 18 | train_loss=0.37310 | val_loss=0.38064
# Epoch 19 | train_loss=0.37278 | val_loss=0.38215
# Epoch 20 | train_loss=0.37251 | val_loss=0.38653

# %% [markdown]
# The VFL LSTM + MLP model trains separate UE-side and RU-side classifier/regressor models. The printed classifier-window count shows the base-user training subset used for local model training, with a large idle majority remaining in the data.
#
# The UE and RU models show different learning behavior because they receive different feature groups. The RU-side model has stronger access to radio-quality and load features, while the UE-side model relies more on position, movement, and traffic-state context. After the local models are trained, their outputs are combined by coordinator models trained on the meta-user split.
#
# This section completes the Neural Network version of the simulated VFL setup. The final comparison later evaluates whether this vertically partitioned model remains close to the centralized LSTM + MLP model.

# %% [markdown]
# ## 16. Final Evaluation Setup on Held-Out Test Users
#
# All saved models are reloaded and evaluated using the same held-out test users. For the Neural Network models, predictions are generated on aligned sequence windows so that centralized, VFL-stacked, and single-device baselines are compared on the same target rows.
#
# Before computing the final test comparison, the notebook also prints a validation summary for the Neural Network models. This provides a sanity check that the saved centralized and VFL Neural Network models reload correctly and still produce the expected validation performance.
#
# The final comparison directly addresses the main project question: whether a VFL-style combination of UE-side and RU-side features can approach the accuracy of a centralized model while keeping raw feature groups separated.

# %% [markdown]
# ### 16.1 Reloading Neural Network Models and Aligning Test Predictions
#
# The following cell reloads the saved centralized LSTM + MLP and VFL-stacked LSTM + MLP models from disk. It then generates predictions on the sequence-aligned test windows and checks that the UE-only, RU-only, centralized, and VFL outputs correspond to the same target rows.
#
# The VFL coordinator diagnostics are also printed to show how strongly the coordinator weights the UE-side and RU-side model outputs.

# %%
print("\n[⌛] Loading Centralized DL Models into RAM...")
central_dl_meta = joblib.load(os.path.join(working_dir, "central_dl_meta.joblib"))
cls_model = HybridLSTMMLP(len(dyn_trained), len(sta_trained)).to(DEVICE)
cls_model.load_state_dict(torch.load(os.path.join(working_dir, "central_dl_cls.pt")))
reg_model = HybridLSTMMLP(len(dyn_trained), len(sta_trained)).to(DEVICE)
reg_model.load_state_dict(torch.load(os.path.join(working_dir, "central_dl_reg.pt")))

central_dl = {
    "cls_model": cls_model, "reg_model": reg_model,
    "threshold": central_dl_meta["threshold"],
    "dynamic_cols": dyn_trained, "static_cols": sta_trained
}

saved_central_threshold = central_dl["threshold"]

dl_cent_pred, y_test, end_idx = predict_centralized_dl(central_dl, test_ann, target, user_col="User_ID", cfg=CFG)
test_tab = rf_test_raw.iloc[end_idx].copy()

# =====================================================================
#   Load VFL deep learning models (LSTM + MLP)
# =====================================================================
print("[⌛] Loading VFL Stacked DL Models into RAM...")
vdl = joblib.load(os.path.join(working_dir, "vfl_dl_coord.joblib"))
ue_cls = HybridLSTMMLP(len(vdl["ue_dyn"]), len(vdl["ue_sta"])).to(DEVICE)
ue_cls.load_state_dict(torch.load(os.path.join(working_dir, "vfl_dl_ue_cls.pt")))
ru_cls = HybridLSTMMLP(len(vdl["ru_dyn"]), len(vdl["ru_sta"])).to(DEVICE)
ru_cls.load_state_dict(torch.load(os.path.join(working_dir, "vfl_dl_ru_cls.pt")))
ue_reg = HybridLSTMMLP(len(vdl["ue_dyn"]), len(vdl["ue_sta"])).to(DEVICE)
ue_reg.load_state_dict(torch.load(os.path.join(working_dir, "vfl_dl_ue_reg.pt")))
ru_reg = HybridLSTMMLP(len(vdl["ru_dyn"]), len(vdl["ru_sta"])).to(DEVICE)
ru_reg.load_state_dict(torch.load(os.path.join(working_dir, "vfl_dl_ru_reg.pt")))

vfl_dl = {
    "ue_cls": ue_cls, "ru_cls": ru_cls, "ue_reg": ue_reg, "ru_reg": ru_reg,
    "coord_clf": vdl["coord_clf"], "coord_reg": vdl["coord_reg"],
    "coord_threshold": vdl.get("coord_threshold", saved_central_threshold),
    "ue_threshold": vdl.get("ue_threshold", saved_central_threshold),
    "ru_threshold": vdl.get("ru_threshold", saved_central_threshold),
    "ue_dyn": vdl["ue_dyn"], "ue_sta": vdl["ue_sta"], "ru_dyn": vdl["ru_dyn"], "ru_sta": vdl["ru_sta"]
}

print("\n" + "="*30 + " DEEP LEARNING VALIDATION SUMMARY " + "="*30)
report_dl_validation(central_dl, vfl_dl, val_ann, target, CFG, user_col="User_ID")

del central_dl, cls_model, reg_model 
clear_memory()

# =====================================================================
#  CRITICAL ALIGNMENT & DEEP LEARNING INFERENCE FIRST
# =====================================================================
print("\n[⌛] Processing Deep Learning Inference & Sequential Alignment...")
vfl_dl_pred = predict_vfl_stacked_dl(vfl_dl, test_ann, target, end_idx, vfl_dl.get("coord_threshold", saved_central_threshold),user_col="User_ID", cfg=CFG)

ue_dl_pred, ue_y, ue_end_idx = predict_single_party_dl(vfl_dl["ue_cls"], vfl_dl["ue_reg"], test_ann, vfl_dl["ue_dyn"], vfl_dl["ue_sta"],target, vfl_dl.get("ue_threshold", saved_central_threshold), user_col="User_ID", cfg=CFG)
ru_dl_pred, ru_y, ru_end_idx = predict_single_party_dl(vfl_dl["ru_cls"], vfl_dl["ru_reg"], test_ann, vfl_dl["ru_dyn"], vfl_dl["ru_sta"],target, vfl_dl.get("ru_threshold", saved_central_threshold), user_col="User_ID", cfg=CFG)

assert np.array_equal(ue_end_idx, end_idx), f"UE end_idx mismatch"
assert np.array_equal(ru_end_idx, end_idx), f"RU end_idx mismatch"
print("\n🔍 VFL COORDINATOR DIAGNOSTICS:")
print("Coordinator Classifier Coefficients (UE weight, RU weight):", vfl_dl["coord_clf"].coef_)

coord_reg = vfl_dl["coord_reg"]
ridge = coord_reg.named_steps["ridge"]
print("Coordinator Regressor Coefficients, standardized space:", ridge.coef_)
print(f"True Active Rate: {(y_test > 0).mean():.4f}\n")

print("[🧹] Purging DL Models from RAM completely...")
del vfl_dl, ue_cls, ru_cls, ue_reg, ru_reg
clear_memory()
# Out:
# [⌛] Loading Centralized DL Models into RAM...
# [⌛] Loading VFL Stacked DL Models into RAM...
#
# ============================== DEEP LEARNING VALIDATION SUMMARY ==============================
#
# =================================================================
#    VALIDATION COMPARISON -- DL-BASED MODELS (val set)
# =================================================================
#                                R2_log  RMSE_log   MAE_log    R2_raw  RMSE_raw  \
# Central LSTM+MLP             0.801782  0.362625  0.164535  0.232573  6.183824
# VFL-Stacked LSTM+MLP         0.801839  0.362574  0.162441  0.241978  6.145814
# UE-Only LSTM+MLP (Baseline)  0.735786  0.418663  0.189857  0.139977  6.546265
# RU-Only LSTM+MLP (Baseline)  0.801532  0.362854  0.163052  0.237107  6.165531
#
#                               MAE_raw
# Central LSTM+MLP             1.197005
# VFL-Stacked LSTM+MLP         1.190740
# UE-Only LSTM+MLP (Baseline)  1.312704
# RU-Only LSTM+MLP (Baseline)  1.193058
# [⌛] Processing Deep Learning Inference & Sequential Alignment...
#
# 🔍 VFL COORDINATOR DIAGNOSTICS:
# Coordinator Classifier Coefficients (UE weight, RU weight): [[ 6.20015304 10.9205756 ]]
# Coordinator Regressor Coefficients, standardized space: [0.02910121 0.4013171 ]
# True Active Rate: 0.1741
#
# [🧹] Purging DL Models from RAM completely...

# %% [markdown]
# The validation summary shows that the VFL-stacked LSTM + MLP performs almost identically to the centralized LSTM + MLP on log-scale R². The VFL model also slightly improves the raw-scale R² on the validation set.
#
# The single-device baselines show an important pattern: the UE-only model performs worse than the RU-only model, while the RU-only model is very close to the centralized and VFL models. This suggests that radio-side features such as SINR, BLER, RU load, and effective signal quality contain most of the predictive information for throughput.
#
# The coordinator diagnostics support the same conclusion. Both the classifier and regressor assign stronger weight to the RU-side output than to the UE-side output. This does not mean the UE features are useless, but it indicates that the radio-unit feature group is the dominant contributor in the VFL Neural Network.

# %% [markdown]
# ### 16.2 Reloading Random Forest Models and Preparing Test Predictions
#
# The following cell reloads the saved Random Forest and Linear VFL models from disk. Predictions are generated on `test_tab`, which contains the same sequence-aligned held-out test rows used by the Neural Network models. This ensures that the final RF, Neural Network, centralized, VFL, UE-only, and RU-only comparisons are evaluated on the same target rows.
#
# The cell also prints a validation summary for the RF-based models as a reload sanity check before the final test-set table is created.

# %%
# =====================================================================
# 1. LOAD CLASSICAL MODELS (RF)
# =====================================================================
print("[⌛] Loading RF Models into RAM...")
central_rf = joblib.load(os.path.join(working_dir, "central_rf.joblib"))
central_rf_pred = predict_centralized_rf(central_rf, test_tab, CFG)

vfl_rf = joblib.load(os.path.join(working_dir, "vfl_rf.joblib"))
vfl_stacked_rf_pred = predict_vfl_stacked_rf(vfl_rf, test_tab)
ue_vfl_rf_pred = predict_single_party_rf(vfl_rf["ue_clf"], vfl_rf["ue_clf_backend"], vfl_rf["ue_reg"], vfl_rf["ue_reg_backend"], test_tab, vfl_rf["ue_features"], CFG)
ru_vfl_rf_pred = predict_single_party_rf(vfl_rf["ru_clf"], vfl_rf["ru_clf_backend"], vfl_rf["ru_reg"], vfl_rf["ru_reg_backend"], test_tab, vfl_rf["ru_features"], CFG)

linear_vfl = joblib.load(os.path.join(working_dir, "linear_vfl.joblib"))
vfl_linear_pred = predict_linear_vfl_baseline(linear_vfl, test_tab)

print("\n" + "="*30 + " CLASSICAL VALIDATION SUMMARY " + "="*30)
report_rf_validation(central_rf, vfl_rf, linear_vfl, rf_val_raw, target, CFG)
# Out:
# [⌛] Loading RF Models into RAM...
#
# ============================== CLASSICAL VALIDATION SUMMARY ==============================
#
# =================================================================
#    VALIDATION COMPARISON -- RF-BASED MODELS (val set)
# =================================================================
#                          R2_log  RMSE_log   MAE_log    R2_raw  RMSE_raw  \
# Central RF             0.798490  0.365808  0.163794  0.233704  6.499554
# VFL-Stacked RF         0.798528  0.365773  0.164147  0.229702  6.516504
# UE-Only RF (Baseline)  0.733492  0.420688  0.187423  0.131299  6.920228
# RU-Only RF (Baseline)  0.797301  0.366885  0.163984  0.234051  6.498085
# Linear VFL             0.768037  0.392477  0.177108  0.149688  6.846594
#
#                         MAE_raw
# Central RF             1.213059
# VFL-Stacked RF         1.206866
# UE-Only RF (Baseline)  1.329119
# RU-Only RF (Baseline)  1.216850
# Linear VFL             1.276066
# {'Central RF': {'R2_log': 0.7984903454780579,
#   'RMSE_log': np.float64(0.3658076188898957),
#   'MAE_log': 0.1637936234474182,
#   'R2_raw': 0.23370438814163208,
#   'RMSE_raw': np.float64(6.499553665095703),
#   'MAE_raw': 1.2130588293075562},
#  'VFL-Stacked RF': {'R2_log': 0.798528254032135,
#   'RMSE_log': np.float64(0.36577317585399344),
#   'MAE_log': 0.1641465574502945,
#   'R2_raw': 0.22970229387283325,
#   'RMSE_raw': np.float64(6.516504022596293),
#   'MAE_raw': 1.206865906715393},
#  'UE-Only RF (Baseline)': {'R2_log': 0.7334917783737183,
#   'RMSE_log': np.float64(0.4206879658212606),
#   'MAE_log': 0.18742261826992035,
#   'R2_raw': 0.13129949569702148,
#   'RMSE_raw': np.float64(6.920228094851038),
#   'MAE_raw': 1.329119324684143},
#  'RU-Only RF (Baseline)': {'R2_log': 0.7973014116287231,
#   'RMSE_log': np.float64(0.3668852028410947),
#   'MAE_log': 0.1639842987060547,
#   'R2_raw': 0.23405075073242188,
#   'RMSE_raw': np.float64(6.498084739801762),
#   'MAE_raw': 1.2168500423431396},
#  'Linear VFL': {'R2_log': 0.7680368423461914,
#   'RMSE_log': np.float64(0.39247706996246234),
#   'MAE_log': 0.17710824310779572,
#   'R2_raw': 0.14968782663345337,
#   'RMSE_raw': np.float64(6.8465938146492205),
#   'MAE_raw': 1.276065707206726}}

# %% [markdown]
# The RF validation summary shows that the centralized RF and VFL-stacked RF perform almost identically on log-scale R². The RU-only RF baseline is also very close to both full-feature models, while the UE-only RF baseline performs noticeably worse.
#
# This pattern is consistent with the Neural Network validation results: radio-side features such as SINR, BLER, RU load, and effective signal quality contain most of the predictive information for throughput. The Linear VFL baseline performs below the RF-based models, which supports the use of nonlinear models for this task.

# %% [markdown]
# ## 17. Final Test-Set Comparison on Held-Out Users

# %% [markdown]
# ### 17.1 Unified Final Evaluation Across All Models
#
# This section compares all final models on the same held-out test users. The evaluation includes centralized models, VFL-style models, and single-device baselines. For fairness, all predictions are evaluated on the same aligned target rows.
#
# Both **log-scale** and **raw-scale** metrics are reported:
#
# - **R²_log** evaluates how well the model captures the general throughput pattern after reducing the influence of extreme values.
# - **RMSE_log** and **MAE_log** summarize prediction error on the log-transformed target.
# - **R²_raw**, **RMSE_raw**, and **MAE_raw** measure performance on the original throughput scale in Mbps.
#
# This final comparison directly addresses the main project question: whether a VFL-style combination of UE-side and RU-side features can approach the performance of a centralized model while keeping the feature groups separated.

# %%
# =====================================================================
# Final unified test-set comparison across all models
# =====================================================================
predictions = {
    "Central RF": central_rf_pred,
    "VFL-Stacked RF": vfl_stacked_rf_pred,
    "Linear VFL Baseline": vfl_linear_pred,
    "UE-Only RF (Single Device)": ue_vfl_rf_pred,
    "RU-Only RF (Single Device)": ru_vfl_rf_pred,
    "Central LSTM+MLP": dl_cent_pred,
    "VFL-Stacked LSTM+MLP": vfl_dl_pred,
    "UE-Only LSTM+MLP (Single Device)": ue_dl_pred,
    "RU-Only LSTM+MLP (Single Device)": ru_dl_pred,
}

results = {name: get_metrics(y_test, pred) for name, pred in predictions.items()}
result_df = print_metric_table(results)

plot_final_comparison(result_df, path="final_vfl_massive_comparison.png")
# Out:
#                                     R2_log  RMSE_log   MAE_log    R2_raw  \
# Central RF                        0.584939  0.429585  0.152797  0.194541
# VFL-Stacked RF                    0.581698  0.431259  0.153017  0.189664
# Linear VFL Baseline               0.669522  0.383322  0.127307  0.115295
# UE-Only RF (Single Device)        0.617247  0.412527  0.145176  0.130197
# RU-Only RF (Single Device)        0.557206  0.443705  0.157455  0.188971
# Central LSTM+MLP                  0.721025  0.352189  0.121392  0.186281
# VFL-Stacked LSTM+MLP              0.710561  0.358733  0.122539  0.218307
# UE-Only LSTM+MLP (Single Device)  0.643740  0.397994  0.138333  0.126149
# RU-Only LSTM+MLP (Single Device)  0.451461  0.493852  0.197535  0.196352
#
#                                   RMSE_raw   MAE_raw
# Central RF                        7.092692  1.101717
# VFL-Stacked RF                    7.114131  1.103854
# Linear VFL Baseline               7.433418  1.000566
# UE-Only RF (Single Device)        7.370547  1.053141
# RU-Only RF (Single Device)        7.117173  1.143115
# Central LSTM+MLP                  7.128966  0.944027
# VFL-Stacked LSTM+MLP              6.987270  0.927841
# UE-Only LSTM+MLP (Single Device)  7.387677  1.025201
# RU-Only LSTM+MLP (Single Device)  7.084714  1.125768

# %% [markdown]
# ### 17.2 Final Test-Set Results and Interpretation
#
# The final test results show that the **centralized LSTM + MLP** achieves the best overall performance on the log scale, with **R²_log = 0.7210**. The **VFL-stacked LSTM + MLP** remains very close, with **R²_log = 0.7106**, showing that the VFL-style neural model preserves most of the centralized model's predictive performance.
#
# Among the Random Forest models, the **centralized RF** and **VFL-stacked RF** perform similarly (**R²_log ≈ 0.58**), but both are clearly below the neural-network models on the log scale. This suggests that temporal modeling provides a meaningful advantage for this task.
#
# The **Linear VFL baseline** performs better than the RF models on the log scale (**R²_log = 0.6695**), but it does not achieve the same overall performance as the LSTM-based models. This makes it a useful reference baseline, while also showing the benefit of more flexible nonlinear models.
#
# The single-device baselines show that performance depends on both the model architecture and the evaluation scale. In the Neural Network setting, the centralized and VFL-stacked LSTM + MLP models clearly outperform the UE-only and RU-only baselines on log-scale R², showing the benefit of combining both feature groups. In the Random Forest setting, the UE-only RF baseline performs competitively on log-scale R², but the centralized and VFL RF models remain stronger on raw-scale explained variance. This confirms that UE-side and RU-side features contribute differently depending on the model and metric.
#
# Overall, the strongest result comes from combining feature groups with the LSTM + MLP architecture, especially in the VFL-stacked model, which remains close to the centralized Neural Network.

# %% [markdown]
# ### 17.3 Reading the Metrics
#
# The metrics should be interpreted carefully because raw-scale and log-scale performance emphasize different behaviors. The throughput target is highly skewed and contains many low or zero values, so **log-scale metrics are the primary measure of general predictive quality**. Raw-scale metrics remain useful, but they are more sensitive to large absolute errors on high-throughput samples.
#
# For this reason, the final discussion prioritizes **R²_log** as the main ranking criterion, while still reporting the raw-scale metrics for completeness.

# %% [markdown]
# ## 18. Results Discussion
#
# The final test-set comparison shows that the Neural Network models achieve stronger log-scale performance than the Random Forest models. The centralized LSTM + MLP obtains the highest log-scale R², while the VFL-stacked LSTM + MLP remains close to it. This is the main finding of the project: vertical feature partitioning can preserve most of the predictive performance of centralized learning.
#
# The Random Forest models provide a useful classical baseline, but their log-scale R² scores are lower than the LSTM + MLP models. This suggests that temporal modeling is helpful for this dataset because throughput depends not only on the current feature values, but also on recent changes in radio quality, load, mobility, and traffic state.
#
# The Linear VFL baseline performs competitively on log-scale metrics, but it is still less flexible than the LSTM-based models. It serves as a required combined linear reference point for the VFL setup.
#
# Raw-scale R² values are lower than log-scale R² values because the throughput target is zero-heavy and contains rare high-throughput peaks. These peaks strongly affect raw RMSE and raw R². Therefore, log-scale metrics are used as the main measure of general predictive quality, while raw-scale metrics are reported for completeness.

# %% [markdown]
# ## 19. Assignment Compliance Summary
#
# The notebook satisfies the Project 9 requirements as follows:
#
# | Requirement | Implementation |
# |---|---|
# | Throughput regression on ACC Arena users | Completed using user-level throughput prediction on the ACC Arena dataset |
# | Random Forest model | Centralized Random Forest and VFL-stacked Random Forest |
# | Neural Network model | Centralized LSTM + MLP and VFL-stacked LSTM + MLP |
# | Use of BLER, PRB, SINR, and traffic values | SINR, BLER, and traffic-state features are included in the clean models; PRB is analyzed as a leakage-risk/upper-bound feature |
# | Team 9 X-meter feature | Crowd-density features are computed using multiple X values: 2m, 5m, and 10m |
# | Experiment with different X values | Crowd-density radius ablation compares 2m, 5m, and 10m |
# | Vertical FL feature split | UE-side and RU-side feature groups are modeled separately; `Crowd_Density_5m` is assigned to the RU/network-side view as local multi-user context |
# | Combined Linear Regressor for VFL | Linear VFL baseline using Logistic Regression and Ridge Regression |
# | Comparison with more complex models | Linear VFL is compared against RF and LSTM + MLP centralized/VFL models |
# | Final output figures and results | Final metric table and R²_log comparison plot are included |

# %% [markdown]
# ## 20. Limitations
#
# This project uses a simulated dense 5G dataset, so the results should be interpreted within the assumptions of the simulation environment. Real-world deployment may include additional sources of noise, missing data, scheduler behavior, and hardware constraints that are not fully represented here.
#
# Throughput prediction is also challenging because the target distribution is highly zero-heavy and contains rare high-throughput peaks. This makes raw-scale regression difficult and explains why raw-scale R² values are lower than log-scale R² values.
#
# The VFL implementation is a simulation of vertical feature partitioning rather than a production federated learning system with secure communication protocols. The notebook does not implement encryption, secure aggregation, or distributed communication. However, it is sufficient for evaluating the assignment requirement of splitting user-terminal and radio-unit features and combining local model outputs.
#
# Finally, the hyperparameter search is intentionally runtime-aware rather than exhaustive. This was necessary because the full aggregated dataset remains large even after preprocessing.

# %% [markdown]
# ## 21. Conclusion
#
# This project successfully predicts user throughput in the ACC Arena dense 5G scenario and compares centralized learning with vertically partitioned learning. The required Team 9 X-meter feature was implemented by counting nearby users within multiple radii, and the final model uses the 5m crowd-density feature as a balanced local-congestion measure.
#
# The results show that Neural Network models, especially the LSTM + MLP architecture, outperform Random Forest models on log-scale throughput prediction. The centralized LSTM + MLP achieves the strongest overall log-scale performance, while the VFL-stacked LSTM + MLP remains close to the centralized model.
#
# Overall, the project demonstrates that a simulated VFL approach can preserve much of the predictive capability of centralized learning while keeping UE-side and RU-side feature groups separated. This supports the feasibility of vertical feature partitioning for throughput prediction in dense 5G environments.
